# %% [markdown]
# ### Model Text/Political Party:
#
#    a. Go to uk_proceedings_clean_subset.csv and create all bigrams/trigrams that are in more than 10 documents.
#
#    b. Go to roberts_rules and create all bigrams/trigrams
#
#    c. Remove all roberts_rules bigrams/trigrams from uk_proceedings bigrams/trigrams
#
#    d. Use Regularized Logistic Regression or SVM to predict Labour/Conservative using the remaining bigrams/trigrams

# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../uk_proceedings_clean.zip', usecols=['PARTY', 'SPEECH_TEXT'])
df
# Out:
#                             PARTY  \
# 0                          Labour
# 1                    Conservative
# 2                          Labour
# 3                             SPK
# 4                             NaN
# 5                          Labour
# 6                    Conservative
# 7               Liberal Democrats
# 8         Scottish National Party
# 9           Ulster Unionist Party
# 10      Democratic Unionist Party
# 11                            SPK
# 12                            SPK
# 13                            SPK
# 14                            SPK
# 15                            SPK
# 16                            SPK
# 17                   Conservative
# 18                   Conservative
# 19          Ulster Unionist Party
# 20                         Labour
# 21        Scottish National Party
# 22                         Labour
# 23                            SPK
# 24                    Plaid Cymru
# 25                         Labour
# 26                            SPK
# 27                            NaN
# 28                            SPK
# 29                   Conservative
# ...                           ...
# 941152          Liberal Democrats
# 941153                     Labour
# 941154          Liberal Democrats
# 941155                     Labour
# 941156               Conservative
# 941157                     Labour
# 941158               Conservative
# 941159                     Labour
# 941160               Conservative
# 941161                     Labour
# 941162               Conservative
# 941163                     Labour
# 941164                        NaN
# 941165                        SPK
# 941166               Conservative
# 941167                        SPK
# 941168               Conservative
# 941169                     Labour
# 941170                        NaN
# 941171                        SPK
# 941172               Conservative
# 941173                     Labour
# 941174          Liberal Democrats
# 941175               Conservative
# 941176                   Alliance
# 941177  Democratic Unionist Party
# 941178                   Alliance
# 941179                Independent
# 941180                   Alliance
# 941181               Conservative
#
#                                               SPEECH_TEXT
# 0       sir edward truli beauti day sun shine god heav...
# 1       sir edward may say delight back leader interru...
# 2       sir edward sat eight speaker like endors every...
# 3       five year sir edward sinc abl address way firs...
# 4       stand upper step take chair speakerelect wish ...
# 5       madam speakerelect rise congratul secur unanim...
# 6       madam speakerelect delight join prime minist c...
# 7       madam speakerelect give great pleasur behalf b...
# 8       behalf joint scottish nation partyplaid cymru ...
# 9       great pleasur rise endors much said alreadi ex...
# 10      congratul madam speakerelect elect speakership...
# 11      report hous hous peer majesti royal commission...
# 12      must call upon member hous accord usual custom...
# 13      member proceed take oath regret report hous de...
# 14      hope possibl morn member wish take oath affirm...
# 15      may conveni hous indic afternoon shall call up...
# 16      wish make statement avail servic hous take sea...
# 17      point order madam speaker extent assent consul...
# 18      point order madam speaker gave notic would ask...
# 19      point order madam speaker may draw attent appe...
# 20      point order madam speaker former member parlia...
# 21      point order madam speaker hon member halesowen...
# 22      point order madam speaker regard statement mem...
# 23      order could deal one subject time allow come b...
# 24      point order madam speaker spoke leader hous ye...
# 25      point order madam speaker confirm revis proced...
# 26                                              quit true
# 27                                                   rose
# 28                         go take point order shall take
# 29      point order madam speaker accept issu decid ma...
# ...                                                   ...
# 941152                             hon gentleman give way
# 941153        think minist take account point quit import
# 941154  right hon gentleman say would like elig criter...
# 941155  write budget dispatch box even stand record gi...
# 941156                       right hon gentleman give way
# 941157  hon gentleman afternoon third area claim bill ...
# 941158                                               rose
# 941159                   never proper answer hope get one
# 941160  let tell right hon gentleman bill introduc pro...
# 941161  right hon gentleman answer question respons cq...
# 941162  shadow secretari state bandi around big word l...
# 941163  took action address care standard nh right hon...
# 941164                                               rose
# 941165  order go call hon member totn dr wollaston app...
# 941166                                       indic assent
# 941167                            call dr sarah wollaston
# 941168  thank mr speaker congratul secretari state gro...
# 941169  want make one brief point care societi deliv l...
# 941170                                               rose
# 941171  order hon member know sympathet everyon tri he...
# 941172  shall make two brief point think two thing bil...
# 941173  shall brief throughout passag bill felt consid...
# 941174  bill deserv third read replac year piecem dog ...
# 941175  great pleasur present petit sign constitu show...
# 941176  grate opportun abl rais import issu access cle...
# 941177  million peopl poor water qualiti billion peopl...
# 941178  agre hon gentleman say right import water sani...
# 941179  grate hon ladi allow interven import adjourn d...
# 941180  thank hon ladi intervent previou highlevel mee...
# 941181  thank hon member belfast east naomi long call ...
#
# [941182 rows x 2 columns]

# %%
df.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#                                      PARTY
# PARTY
# Alliance                               278
# CWM                                   5709
# Conservative                        336361
# DCWM                                 10996
# Democratic Unionist Party             6014
# Green                                  756
# Independent                           1324
# Independent Conservative                46
# Independent Labour                      44
# Independent Ulster Unionist             89
# Labour                              442763
# Liberal Democrats                    83142
# Plaid Cymru                           5212
# Respect                                122
# SPK                                  18501
# Scottish National Party               9537
# Social Democratic and Labour Party    2297
# Ulster Unionist Party                 4087
# United Kingdom Independence Party      107
# United Kingdom Unionist Party          282

# %%
sdf = df[df.PARTY.isin(['Labour', 'Conservative']) & df.SPEECH_TEXT.notnull()]

# %%
sdf.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#                PARTY
# PARTY
# Conservative  335283
# Labour        441703

# %%
import random

def RandomSample(data, size):
    """Returns random sample for given size
       If training data set is too big, we can reduce its size
    """
    return data.ix[random.sample(data.index, size)]


def StratifiedSample(data, nperlabel, label='label'):
    """Returns stratified data with N per label
    """
    sample = pd.DataFrame()
    datagrp = data.groupby(label)
    sortedgrp = datagrp.size().sort_values(ascending=False)
    for i, l in enumerate(sortedgrp.index):
        if sortedgrp[l] > nperlabel:
            print("==> %-50s %6d" % (l, sortedgrp[l]))
            sample = sample.append(RandomSample(data[data[label] == l],
                                   nperlabel))
        else:
            break
    print("There are %d labels have more than %d articles" % (i + 1, nperlabel))
    print("Sample size: %s articles" % (len(sample)))
    return sample

# %%
N_PER_LABEL = 20000

subset = StratifiedSample(sdf, N_PER_LABEL, 'PARTY')
# Out:
# ==> Labour                                             441703
# ==> Conservative                                       335283
# There are 2 labels have more than 20000 articles
# Sample size: 40000 articles

# %%
subset
# Out:
#                PARTY                                        SPEECH_TEXT
# 703630        Labour  would disservic mani million peopl affectedcer...
# 467190        Labour  must make progress although sixhour debat take...
# 384464        Labour  hon gentleman paid tribut organis work disabl ...
# 457242        Labour  examin potenti scenario test nuclear hypothesi...
# 789066        Labour  minist ask allparti financi mutual inquiri pub...
# 750858        Labour  last labour govern oversaw greatest renaiss ci...
# 47885         Labour  first point confirm said would statement tomor...
# 324085        Labour  grate inform hon gentleman give subject shall ...
# 449184        Labour  assur hon friend shall commun chairman crimin ...
# 664752        Labour  secretari state realis opposit parti parliamen...
# 394933        Labour  consid econom implic polici regard british ene...
# 185174        Labour  sometim wish journalist remark well inform res...
# 208795        Labour  take counsel hon friend shall need look care d...
# 358294        Labour  much agre hon friend absolut right know share ...
# 319485        Labour  indic substanti chang section duti consult ove...
# 329151        Labour                             point order mr speaker
# 459743        Labour  hon ladi came wale ask peoplewheth pontypool m...
# 539889        Labour  talk commerci arrang firm governmenta commerci...
# 180378        Labour  thank hon friend answer one thing told us howe...
# 428320        Labour  recognis concern within hous chang requir take...
# 544728        Labour  proud honorari unpaid advis port tilburi polic...
# 263510        Labour  hon gentleman confirm answer ye support civil ...
# 753455        Labour  hon friend teas import element amend northern ...
# 158263        Labour  greatli sympathis hon gentleman point although...
# 486527        Labour                          right hon friend give way
# 350783        Labour  first hon gentleman confirm conserv parti brou...
# 375666        Labour  hon gentleman made specif point might abl help...
# 556026        Labour  ye import hesit tell local author alway object...
# 404600        Labour  consist recognis point unfortun hon gentleman ...
# 526223        Labour  right promis peopl money know deliv right type...
# ...              ...                                                ...
# 599340  Conservative  first may apologis fact present speech leader ...
# 761822  Conservative  obvious look whether individu access support w...
# 809185  Conservative  ye absolut sure g4 contract trebl end judgment...
# 754736  Conservative  give way moment strategi made clear matter pat...
# 156536  Conservative  grate right hon friend reinforc difficulti fin...
# 4846    Conservative  grate opportun speak briefli tonightal conscio...
# 102164  Conservative  unlik labour member free thinker need aid put ...
# 833851  Conservative  consider church commission given use inclus ad...
# 345735  Conservative  sorri interven yet could hon gentleman explain...
# 915609  Conservative  may earli debat local govern financ would enab...
# 886909  Conservative  apologis hon ladi leav chamberi chair debat we...
# 747815  Conservative  assess made trend level dissid activ northern ...
# 468047  Conservative  opposit wish sir david henshaw well mission co...
# 805315  Conservative  exampl central bank canadian spanish central b...
# 715827  Conservative  select committe northern ireland met assist co...
# 867195  Conservative  fair parti give way hon gentleman scottish nat...
# 569330  Conservative  partli parliament support european union make ...
# 469968  Conservative  certainli would want rehears argument madam de...
# 704704  Conservative  grate opportun make first formal contribut deb...
# 785702  Conservative  power intervent depart intern develop respons ...
# 622307  Conservative  rememb debat committe point one danger transpa...
# 708989  Conservative  thank right hon friend honour done put commiss...
# 195794  Conservative  minist accept one greatest disincent competit ...
# 769017  Conservative  thank govern speedi action issu right hon frie...
# 295704  Conservative  lord chancellor formal inquir law procedur jud...
# 356895  Conservative  longterm care elderli clearli complic import i...
# 355590  Conservative  let deal point principl first favour claus ans...
# 857389  Conservative  prime minist confirm report provid us fullest ...
# 109435  Conservative  today triumph minist would like peopl believ i...
# 286623  Conservative  secretari state agre longterm reconstruct afgh...
#
# [40000 rows x 2 columns]

# %%
#subset.to_csv('/tmp/subset.csv.gz', compression='gzip', index=False)

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(subset.SPEECH_TEXT, subset.PARTY, test_size=0.2)

# %%
all_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10)
all_vect.fit(X_train.astype(str))
vocab = []
i = 0
for a in all_vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 969
# Total 28246

# %%
train_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10, vocabulary=vocab)

# %%
X_train = train_vect.transform(X_train.astype(str))
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = train_vect.transform(X_test.astype(str))
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
# Perform classification with SVM, kernel=rbf
classifier_rbf = svm.SVC()
t0 = time.time()
classifier_rbf.fit(X_train, y_train)
t1 = time.time()
prediction_rbf = classifier_rbf.predict(X_test)
t2 = time.time()
time_rbf_train = t1-t0
time_rbf_predict = t2-t1

# Print results in a nice table
print("Results for SVC(kernel=rbf)")
print("Training time: %fs; Prediction time: %fs" % (time_rbf_train, time_rbf_predict))
print(classification_report(y_test, prediction_rbf))
# Out:
# Results for SVC(kernel=rbf)
# Training time: 418.881899s; Prediction time: 97.778848s
#              precision    recall  f1-score   support
#
# Conservative       0.50      1.00      0.67      3991
#      Labour       0.00      0.00      0.00      4009
#
# avg / total       0.25      0.50      0.33      8000
# /opt/venv/local/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Perform classification with SVM, kernel=linear
classifier_linear = svm.SVC(kernel='linear')
t0 = time.time()
classifier_linear.fit(X_train, y_train)
t1 = time.time()
prediction_linear = classifier_linear.predict(X_test)
t2 = time.time()
time_linear_train = t1-t0
time_linear_predict = t2-t1

print("Results for SVC(kernel=linear)")
print("Training time: %fs; Prediction time: %fs" % (time_linear_train, time_linear_predict))
print(classification_report(y_test, prediction_linear))
# Out:
# Results for SVC(kernel=linear)
# Training time: 584.533539s; Prediction time: 51.560148s
#              precision    recall  f1-score   support
#
# Conservative       0.65      0.68      0.67      3991
#      Labour       0.67      0.64      0.65      4009
#
# avg / total       0.66      0.66      0.66      8000

# %%
# Perform classification with SVM, kernel=linear
classifier_liblinear = svm.LinearSVC()
t0 = time.time()
classifier_liblinear.fit(X_train, y_train)
t1 = time.time()
prediction_liblinear = classifier_liblinear.predict(X_test)
t2 = time.time()
time_liblinear_train = t1-t0
time_liblinear_predict = t2-t1

print("Results for LinearSVC()")
print("Training time: %fs; Prediction time: %fs" % (time_liblinear_train, time_liblinear_predict))
print(classification_report(y_test, prediction_liblinear))
# Out:
# Results for LinearSVC()
# Training time: 0.448868s; Prediction time: 0.001059s
#              precision    recall  f1-score   support
#
# Conservative       0.64      0.66      0.65      3991
#      Labour       0.65      0.62      0.63      4009
#
# avg / total       0.64      0.64      0.64      8000

# %%
from sklearn.linear_model import SGDClassifier

elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
t0 = time.time()
elastic_clf.fit(X_train, y_train)
t1 = time.time()
prediction_elastic = elastic_clf.predict(X_test)
t2 = time.time()
time_elastic_train = t1-t0
time_elastic_predict = t2-t1

print("Results for Elastic Net()")
print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
print(classification_report(y_test, prediction_elastic))
# Out:
# Results for Elastic Net()
# Training time: 4.379103s; Prediction time: 0.001238s
#              precision    recall  f1-score   support
#
# Conservative       0.66      0.68      0.67      3991
#      Labour       0.67      0.65      0.66      4009
#
# avg / total       0.66      0.66      0.66      8000

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print "\t%.4f\t%-20s\t\t%.4f\t%-20s" % (coef_1, fn_1, coef_2, fn_2)

# %%
show_most_informative_features(train_vect, elastic_clf, 100)
# Out:
# 	-4.9061	labour member       		4.5134	conserv parti
# 	-3.8063	labour parti        		3.7013	friend minist
# 	-3.4125	secretari state     		3.1306	friend member birmingham
# 	-3.2792	paymast gener       		3.1031	tori parti
# 	-3.2665	leader hou          		3.0677	bedroom tax
# 	-3.2570	hon member birmingham		2.8464	hon member bromley
# 	-2.8507	minist agr          		2.8195	hon friend minist
# 	-2.7511	financ secretari    		2.7490	wide rang
# 	-2.7088	hon member rhondda  		2.6880	conserv member
# 	-2.6190	hon ladi            		2.6076	right hon friend
# 	-2.5641	work experi         		2.5640	tori govern
# 	-2.5572	european court      		2.5035	learn gentleman
# 	-2.5040	friend member south 		2.5035	hon learn gentleman
# 	-2.4980	grate minist        		2.4959	hon member stone
# 	-2.4526	hon learn ladi      		2.4794	hon member richmond
# 	-2.4526	learn ladi          		2.4197	energi compani
# 	-2.4135	friend member bromley		2.4142	hon member wokingham
# 	-2.4004	hon member birkenhead		2.2580	hon member buckingham
# 	-2.3237	econom secretari    		2.2541	friend member rhondda
# 	-2.3079	minist mention      		2.2186	hon learn member
# 	-2.2374	minist said         		2.1812	northeast england
# 	-2.1919	hon member leicest  		2.1698	friend member walsal
# 	-2.1868	friend member buckingham		2.1563	hou mr
# 	-2.1467	work programm       		2.1111	learn member
# 	-2.1324	hon member edinburgh		2.0869	ensur peopl
# 	-2.0994	hon member glasgow  		2.0697	lowincom famili
# 	-2.0818	know minist         		2.0555	cut public
# 	-2.0594	minist accept       		2.0224	gentleman parti
# 	-2.0372	hon member liverpool		2.0030	hon gentleman parti
# 	-2.0342	budget deficit      		1.9801	hon member haltempr
# 	-2.0303	minist right        		1.9698	health servic
# 	-2.0214	minist argument     		1.9518	new contract
# 	-2.0039	prime minist        		1.9426	issu consid
# 	-2.0030	tax rise            		1.9279	friend member hendon
# 	-1.9968	minist say          		1.9231	tax cut
# 	-1.9899	sir alan            		1.9172	friend leader hou
# 	-1.9771	unintend consequ    		1.9144	hon member east
# 	-1.9757	minist explain      		1.9059	hon member maidston
# 	-1.9725	learn friend member 		1.8854	make avail
# 	-1.9676	delight hear        		1.8678	way forward
# 	-1.9628	order paper         		1.8634	domest violenc
# 	-1.9515	new labour          		1.8578	extra invest
# 	-1.9284	hon member nottingham		1.8535	friend repli
# 	-1.9277	coalit govern       		1.8239	depriv area
# 	-1.9276	minist awar         		1.8062	ident card
# 	-1.9184	friend member       		1.8047	concern hon
# 	-1.9165	upper hou           		1.8009	hon member beaconsfield
# 	-1.9066	govern think        		1.8008	assur hon
# 	-1.9016	year labour         		1.7948	iraqi peopl
# 	-1.8830	busi rate           		1.7926	hon member woodspr
# 	-1.8610	hou adjourn         		1.7901	rang measur
# 	-1.8510	minist believ       		1.7700	mani women
# 	-1.8489	year govern         		1.7683	middl east
# 	-1.8435	govern action       		1.7646	want hon
# 	-1.8416	friend member richmond		1.7615	rate cent
# 	-1.8415	coalit agreement    		1.7504	hon member southwest
# 	-1.8386	timet motion        		1.7450	older peopl
# 	-1.8292	red tape            		1.7325	poorest pension
# 	-1.8151	minist abl          		1.7323	possibl hon
# 	-1.7994	second read         		1.7266	given way hon
# 	-1.7969	govern want         		1.7204	sure hou
# 	-1.7928	friend member north 		1.7113	friend comment
# 	-1.7896	friend member southwest		1.7080	new opportun
# 	-1.7889	hon member leigh    		1.7055	hon member south
# 	-1.7882	minist reassur      		1.6958	lord said
# 	-1.7827	hope hon ladi       		1.6933	new deal
# 	-1.7811	understand govern   		1.6887	bu servic
# 	-1.7737	friend member christchurch		1.6871	friend member glasgow
# 	-1.7664	hon member cardiff  		1.6869	new way
# 	-1.7647	huge increa         		1.6842	public transport
# 	-1.7629	sinn feinira        		1.6708	steel industri
# 	-1.7512	reassur hon friend  		1.6589	bank levi
# 	-1.7274	friend member suffolk		1.6539	friend member birkenhead
# 	-1.7269	hon member manchest 		1.6526	friend member edinburgh
# 	-1.7253	friend member gainsborough		1.6515	hon friend repli
# 	-1.7236	meanstest benefit   		1.6497	hon member northwest
# 	-1.7204	polit correct       		1.6461	friend member leicest
# 	-1.7184	howev minist        		1.6455	hon friend secretari
# 	-1.7141	make save           		1.6448	friend secretari
# 	-1.7138	friend member stone 		1.6370	conserv govern
# 	-1.7073	right hon gentleman 		1.6356	ethnic minor
# 	-1.7017	accept mani         		1.6335	shall certainli
# 	-1.7006	look care           		1.6273	friend secretari state
# 	-1.6957	absolut right       		1.6259	alreadi said
# 	-1.6956	hon member linlithgow		1.6228	welfar state
# 	-1.6901	minist prepar       		1.6166	prebudget report
# 	-1.6875	ministri justic     		1.6044	near futur
# 	-1.6874	spend money         		1.6011	liber parti
# 	-1.6855	hon member luton    		1.6007	legal action
# 	-1.6728	regist vote         		1.6004	discuss hon
# 	-1.6728	minist talk         		1.5932	real issu
# 	-1.6726	minist make         		1.5925	friend member liverpool
# 	-1.6716	tax govern          		1.5924	parti make
# 	-1.6480	knowledg matter     		1.5909	addit resourc
# 	-1.6431	ask govern          		1.5895	welcom propo
# 	-1.6320	hon learn friend    		1.5879	said clearli
# 	-1.6271	tax revenu          		1.5876	sierra leon
# 	-1.6239	victim crime        		1.5810	consid way
# 	-1.6144	govern came         		1.5759	avail year
# 	-1.6040	friend member haltempr		1.5673	school constitu

# %%
elastic_clf.predict_proba(X_test)
# Out:
# array([[ 0.57070082,  0.42929918],
#        [ 0.71435708,  0.28564292],
#        [ 0.38103458,  0.61896542],
#        ...,
#        [ 0.75160613,  0.24839387],
#        [ 0.52588482,  0.47411518],
#        [ 0.31653077,  0.68346923]])

# %%
X_test.shape
# Out:
# (8000, 28246)
