# %% [markdown]
# ### Model Text/Political Party:
#
#    a. Go to uk_proceedings_clean_subset.csv and create all bigrams/trigrams that are in more than 10 documents.
#
#    b. Go to roberts_rules and create all bigrams/trigrams
#
#    c. Remove all roberts_rules bigrams/trigrams from uk_proceedings bigrams/trigrams
#
#    d. Use Regularized Logistic Regression or SVM to predict Labour/Conservative using the remaining bigrams/trigrams

# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../uk_proceedings_clean.zip', usecols=['PARTY', 'SPEECH_TEXT'])
df
# Out:
#                             PARTY  \
# 0                          Labour
# 1                    Conservative
# 2                          Labour
# 3                             SPK
# 4                             NaN
# 5                          Labour
# 6                    Conservative
# 7               Liberal Democrats
# 8         Scottish National Party
# 9           Ulster Unionist Party
# 10      Democratic Unionist Party
# 11                            SPK
# 12                            SPK
# 13                            SPK
# 14                            SPK
# 15                            SPK
# 16                            SPK
# 17                   Conservative
# 18                   Conservative
# 19          Ulster Unionist Party
# 20                         Labour
# 21        Scottish National Party
# 22                         Labour
# 23                            SPK
# 24                    Plaid Cymru
# 25                         Labour
# 26                            SPK
# 27                            NaN
# 28                            SPK
# 29                   Conservative
# ...                           ...
# 941152          Liberal Democrats
# 941153                     Labour
# 941154          Liberal Democrats
# 941155                     Labour
# 941156               Conservative
# 941157                     Labour
# 941158               Conservative
# 941159                     Labour
# 941160               Conservative
# 941161                     Labour
# 941162               Conservative
# 941163                     Labour
# 941164                        NaN
# 941165                        SPK
# 941166               Conservative
# 941167                        SPK
# 941168               Conservative
# 941169                     Labour
# 941170                        NaN
# 941171                        SPK
# 941172               Conservative
# 941173                     Labour
# 941174          Liberal Democrats
# 941175               Conservative
# 941176                   Alliance
# 941177  Democratic Unionist Party
# 941178                   Alliance
# 941179                Independent
# 941180                   Alliance
# 941181               Conservative
#
#                                               SPEECH_TEXT
# 0       sir edward truli beauti day sun shine god heav...
# 1       sir edward may say delight back leader interru...
# 2       sir edward sat eight speaker like endors every...
# 3       five year sir edward sinc abl address way firs...
# 4       stand upper step take chair speakerelect wish ...
# 5       madam speakerelect rise congratul secur unanim...
# 6       madam speakerelect delight join prime minist c...
# 7       madam speakerelect give great pleasur behalf b...
# 8       behalf joint scottish nation partyplaid cymru ...
# 9       great pleasur rise endors much said alreadi ex...
# 10      congratul madam speakerelect elect speakership...
# 11      report hous hous peer majesti royal commission...
# 12      must call upon member hous accord usual custom...
# 13      member proceed take oath regret report hous de...
# 14      hope possibl morn member wish take oath affirm...
# 15      may conveni hous indic afternoon shall call up...
# 16      wish make statement avail servic hous take sea...
# 17      point order madam speaker extent assent consul...
# 18      point order madam speaker gave notic would ask...
# 19      point order madam speaker may draw attent appe...
# 20      point order madam speaker former member parlia...
# 21      point order madam speaker hon member halesowen...
# 22      point order madam speaker regard statement mem...
# 23      order could deal one subject time allow come b...
# 24      point order madam speaker spoke leader hous ye...
# 25      point order madam speaker confirm revis proced...
# 26                                              quit true
# 27                                                   rose
# 28                         go take point order shall take
# 29      point order madam speaker accept issu decid ma...
# ...                                                   ...
# 941152                             hon gentleman give way
# 941153        think minist take account point quit import
# 941154  right hon gentleman say would like elig criter...
# 941155  write budget dispatch box even stand record gi...
# 941156                       right hon gentleman give way
# 941157  hon gentleman afternoon third area claim bill ...
# 941158                                               rose
# 941159                   never proper answer hope get one
# 941160  let tell right hon gentleman bill introduc pro...
# 941161  right hon gentleman answer question respons cq...
# 941162  shadow secretari state bandi around big word l...
# 941163  took action address care standard nh right hon...
# 941164                                               rose
# 941165  order go call hon member totn dr wollaston app...
# 941166                                       indic assent
# 941167                            call dr sarah wollaston
# 941168  thank mr speaker congratul secretari state gro...
# 941169  want make one brief point care societi deliv l...
# 941170                                               rose
# 941171  order hon member know sympathet everyon tri he...
# 941172  shall make two brief point think two thing bil...
# 941173  shall brief throughout passag bill felt consid...
# 941174  bill deserv third read replac year piecem dog ...
# 941175  great pleasur present petit sign constitu show...
# 941176  grate opportun abl rais import issu access cle...
# 941177  million peopl poor water qualiti billion peopl...
# 941178  agre hon gentleman say right import water sani...
# 941179  grate hon ladi allow interven import adjourn d...
# 941180  thank hon ladi intervent previou highlevel mee...
# 941181  thank hon member belfast east naomi long call ...
#
# [941182 rows x 2 columns]

# %%
df.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#                                      PARTY
# PARTY
# Alliance                               278
# CWM                                   5709
# Conservative                        336361
# DCWM                                 10996
# Democratic Unionist Party             6014
# Green                                  756
# Independent                           1324
# Independent Conservative                46
# Independent Labour                      44
# Independent Ulster Unionist             89
# Labour                              442763
# Liberal Democrats                    83142
# Plaid Cymru                           5212
# Respect                                122
# SPK                                  18501
# Scottish National Party               9537
# Social Democratic and Labour Party    2297
# Ulster Unionist Party                 4087
# United Kingdom Independence Party      107
# United Kingdom Unionist Party          282

# %%
sdf = df[df.PARTY.isin(['Labour', 'Conservative']) & df.SPEECH_TEXT.notnull()]

# %%
sdf.loc[:, 'textlen'] = sdf.loc[:, 'SPEECH_TEXT'].apply(lambda c: len(c))
# Out:
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
sdf = sdf[sdf.textlen >= 2000]

# %%
sdf.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#               PARTY
# PARTY
# Conservative  22299
# Labour        27301

# %%
import random

def RandomSample(data, size):
    """Returns random sample for given size
       If training data set is too big, we can reduce its size
    """
    return data.ix[random.sample(data.index, size)]


def StratifiedSample(data, nperlabel, label='label'):
    """Returns stratified data with N per label
    """
    sample = pd.DataFrame()
    datagrp = data.groupby(label)
    sortedgrp = datagrp.size().sort_values(ascending=False)
    for i, l in enumerate(sortedgrp.index):
        if sortedgrp[l] > nperlabel:
            print("==> %-50s %6d" % (l, sortedgrp[l]))
            sample = sample.append(RandomSample(data[data[label] == l],
                                   nperlabel))
        else:
            break
    print("There are %d labels have more than %d articles" % (i + 1, nperlabel))
    print("Sample size: %s articles" % (len(sample)))
    return sample

# %%
N_PER_LABEL = 10000

subset = StratifiedSample(sdf, N_PER_LABEL, 'PARTY')
# Out:
# ==> Labour                                              27301
# ==> Conservative                                        22299
# There are 2 labels have more than 10000 articles
# Sample size: 20000 articles

# %%
subset
# Out:
#                PARTY                                        SPEECH_TEXT  \
# 544470        Labour  debat govern draft legisl programmeth list bil...
# 684590        Labour  absolut pleasur follow hon member midsussex mr...
# 585115        Labour  give hon gentleman assur respect balanc struck...
# 506719        Labour  thank hon gentleman know well understand point...
# 284884        Labour  withdraw saidi want record point appear made c...
# 547156        Labour  govern respons report accept recommend made im...
# 930616        Labour  agre get away fact see whole brew industri pub...
# 194502        Labour  grate opportun rais regul care commun scheme f...
# 642068        Labour  apologis right hon friend secretari state oppo...
# 653926        Labour  soldier kill afghanistan kyle adam charlen bar...
# 278778        Labour  alway enjoy follow hon member west suffolk mr ...
# 119452        Labour  member public account committe visit brussel l...
# 859088        Labour  thank secretari state advanc copi quarterli st...
# 41160         Labour  agre hon friend import tri improv democraci lo...
# 94043         Labour  hear remark hon friend refer quit right paedop...
# 458115        Labour  join hon member congratul right hon friend mem...
# 134196        Labour  join right hon friend member north durham mr r...
# 253641        Labour  grate opportun address hous white paper deserv...
# 177262        Labour  schoolboy debat point shall wast time debat ho...
# 797832        Labour  draw hous attent indirect interest regist memb...
# 247798        Labour  leav hous madam deputi speaker want respond br...
# 359346        Labour  civil servant could put better hon friend earl...
# 38078         Labour  much welcom debat indebt hon friend member gra...
# 219955        Labour  heard much conserv member inadequaci spend nat...
# 222027        Labour  like mani member welcom bill receiv larg numbe...
# 111533        Labour  inde hon friend absolut correct supermarket st...
# 553242        Labour  look forward visit buri engag public debat imp...
# 10325         Labour  respond gener question other hous great strugg...
# 454841        Labour  may begin send good wish everyon work hous lea...
# 518547        Labour  matter need explor committe work accept intent...
# ...              ...                                                ...
# 139069  Conservative  congratul hon member oxford west abingdon dr h...
# 429173  Conservative  grate opportun offer first contribut hous impo...
# 656623  Conservative  grate opportun tonight rais case constitu fabi...
# 260523  Conservative  would like review new claus style miss world c...
# 297683  Conservative  stage proceed often said good debat sat almost...
# 67288   Conservative  pay tribut fellow conserv back bencher committ...
# 79150   Conservative  select committe report extrem help subject cle...
# 279779  Conservative  hon friend anticip argument shall deploy later...
# 29587   Conservative  shall give way hon gentleman mind view shortag...
# 627157  Conservative  pleas sum conserv bench live debat time avail ...
# 54657   Conservative  shall brief hon member must welcom step toward...
# 727581  Conservative  pleasur honour particip import debat follow ho...
# 633880  Conservative  acknowledg sensibl seri measur introduc addres...
# 734621  Conservative  thank hon friend member enfield southgat mr bu...
# 37168   Conservative  ye increas council tax look bottom line hon fr...
# 490193  Conservative  mix feel rise speak third read hope support bi...
# 46196   Conservative  beg move amend page line state insert save day...
# 56360   Conservative  strongli support amend shall abl briefli right...
# 350835  Conservative  must admit hope new secretari state took respo...
# 138090  Conservative  great pleasur tell hon friend etho one good tu...
# 339283  Conservative  glad opportun comment amend hon member observ ...
# 231765  Conservative  thank madam deputi speaker give opportun make ...
# 612347  Conservative  night hon member great grimsbi mr mitchel elec...
# 471744  Conservative  great pleasur follow hon friend member southwe...
# 433308  Conservative  grate opportun particip debat also privileg fo...
# 764885  Conservative  grate hon friend rais issu address later speec...
# 755349  Conservative  delight hear hon member liverpool wavertre luc...
# 176309  Conservative  hon member wellingborough mr stinchcomb made d...
# 600625  Conservative  thank mr deputi speaker may take opportun than...
# 897579  Conservative  address point rais hon gentleman mention peac ...
#
#         textlen
# 544470     2448
# 684590     4331
# 585115     2291
# 506719     4902
# 284884     4521
# 547156     2453
# 930616     2591
# 194502     6503
# 642068     4507
# 653926     2357
# 278778     3013
# 119452     2666
# 859088     2921
# 41160      2163
# 94043      3362
# 458115     3462
# 134196     3061
# 253641     2807
# 177262     2086
# 797832     2534
# 247798     4211
# 359346     4296
# 38078      2943
# 219955     4104
# 222027     6649
# 111533     2545
# 553242     2018
# 10325      2487
# 454841     6409
# 518547     2275
# ...         ...
# 139069     2663
# 429173     6648
# 656623     8426
# 260523     4356
# 297683     2240
# 67288      2413
# 79150      3480
# 279779     2191
# 29587      2494
# 627157     6611
# 54657      2507
# 727581     2153
# 633880     6525
# 734621     2419
# 37168      3637
# 490193     4251
# 46196      3264
# 56360      3190
# 350835     4397
# 138090     3017
# 339283     2204
# 231765     5456
# 612347     8992
# 471744     2752
# 433308     4318
# 764885     3370
# 755349     6175
# 176309     2568
# 600625     4724
# 897579     2845
#
# [20000 rows x 3 columns]

# %%
#subset.to_csv('/tmp/subset.csv.gz', compression='gzip', index=False)

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(subset.SPEECH_TEXT, subset.PARTY, test_size=0.2, random_state=42)

# %%
#all_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10)
all_vect = CountVectorizer(ngram_range=(2, 3), min_df=10)
#all_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, stop_words=['friend', 'member', 'hon', 'ladi', 'gentleman'])
all_vect.fit(X_train.astype(str))
vocab = []
i = 0
for a in all_vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 2554
# Total 136604

# %%
uk_media_ngram = pd.read_csv('../data/uk_media_50k_23gram.csv')

# %%
uk_media_vocab = uk_media_ngram[uk_media_ngram.ngram.isin(vocab)]

# %%
len(uk_media_ngram)
# Out:
# 169217

# %%
len(uk_media_vocab)
# Out:
# 47800

# %%
#train_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10, vocabulary=vocab)
train_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=uk_media_vocab.ngram)
#train_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=vocab, stop_words=['friend', 'member', 'hon', 'ladi', 'gentleman'])

# %%
X_train = train_vect.transform(X_train.astype(str))
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = train_vect.transform(X_test.astype(str))
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
from sklearn.linear_model import SGDClassifier

elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
t0 = time.time()
elastic_clf.fit(X_train, y_train)
t1 = time.time()
prediction_elastic = elastic_clf.predict(X_test)
t2 = time.time()
time_elastic_train = t1-t0
time_elastic_predict = t2-t1

print("Results for Elastic Net")
print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
print(classification_report(y_test, prediction_elastic))
# Out:
# Results for Elastic Net
# Training time: 9.302912s; Prediction time: 0.003244s
#              precision    recall  f1-score   support
#
# Conservative       0.74      0.74      0.74      1981
#      Labour       0.74      0.74      0.74      2019
#
# avg / total       0.74      0.74      0.74      4000

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print "\t%.4f\t%-20s\t\t%.4f\t%-20s" % (coef_1, fn_1, coef_2, fn_2)

# %%
show_most_informative_features(train_vect, elastic_clf, 100)
# Out:
# 	-6.6304	labour member       		7.3809	friend home
# 	-6.0219	offici report       		6.3868	tori govern
# 	-5.2847	minist may          		4.2237	tori parti
# 	-5.0986	secretari state     		4.1004	trade union
# 	-4.9075	financi secretari   		4.0034	opposit parti
# 	-4.7959	minist said         		3.9778	busi secretari
# 	-4.5309	labour parti        		3.9404	conserv parti
# 	-4.1650	agre hous           		3.6646	govern member
# 	-4.0415	minist would        		3.6187	south yorkshir
# 	-3.7203	declar interest     		3.4849	previou administr
# 	-3.6841	govern seem         		3.3649	conserv member
# 	-3.6819	good point          		3.3611	point rais
# 	-3.5834	side hous           		3.3147	bedroom tax
# 	-3.5536	coalit govern       		3.3115	work peopl
# 	-3.5455	polit correct       		3.2947	south wale
# 	-3.4824	tell us             		3.2693	greater manchest
# 	-3.3178	public financ       		3.2446	unit nation
# 	-3.3004	great pleasur       		3.2235	new deal
# 	-3.2678	may well            		3.1906	spend cut
# 	-3.2425	fact govern         		3.1136	also ask
# 	-3.2357	red tape            		3.0286	labour govern
# 	-3.1708	would like          		3.0172	much welcom
# 	-3.1335	govern intend       		3.0148	good practic
# 	-3.1286	last govern         		3.0064	lib dem
# 	-3.0874	european court      		3.0062	way forward
# 	-3.0866	minist confirm      		2.9311	next week
# 	-3.0447	new labour          		2.8667	work togeth
# 	-3.0427	minist agre         		2.8504	tax cut
# 	-2.9675	govern may          		2.8465	poll tax
# 	-2.9531	would enabl         		2.7945	manifesto commit
# 	-2.8798	would grate         		2.7723	meet need
# 	-2.7956	hous built          		2.7178	doubledip recess
# 	-2.7928	nation interest     		2.6863	local govern
# 	-2.7859	govern say          		2.6733	peopl work
# 	-2.7791	govern fail         		2.6662	also provid
# 	-2.7732	prime minist        		2.6027	vast major
# 	-2.7691	minist give         		2.5914	long overdu
# 	-2.7537	statement hous      		2.5731	futur job
# 	-2.7436	govern think        		2.5662	later year
# 	-2.7231	anoth exampl        		2.5441	wast manag
# 	-2.7187	minist state        		2.5330	govern commit
# 	-2.7151	grammar school      		2.4792	welfar state
# 	-2.6909	south west          		2.4791	take forward
# 	-2.6741	govern claim        		2.4752	first time
# 	-2.6280	move hous           		2.4439	follow consult
# 	-2.6240	one thing           		2.4355	winter fuel
# 	-2.6086	govern seek         		2.4285	coal mine
# 	-2.5991	home secretari      		2.4153	averag earn
# 	-2.5520	yet anoth           		2.4041	world bank
# 	-2.5479	budget deficit      		2.4004	daili mail
# 	-2.5339	none less           		2.3927	missil defenc
# 	-2.5128	increas cost        		2.3451	public interest
# 	-2.4978	town centr          		2.3036	transport system
# 	-2.4939	person account      		2.2798	econom social
# 	-2.4755	district council    		2.2483	would inappropri
# 	-2.4748	minist say          		2.2477	let say
# 	-2.4506	govern failur       		2.2256	govern open
# 	-2.4346	pupil premium       		2.2219	job growth
# 	-2.4258	quit lot            		2.2016	bank levi
# 	-2.4134	said govern         		2.1783	hope right
# 	-2.4083	reform public       		2.1652	hunt dog
# 	-2.4030	govern tri          		2.1602	committe agre
# 	-2.3966	absolut right       		2.1528	food bank
# 	-2.3911	hold govern         		2.1328	invest public
# 	-2.3821	margaret thatcher   		2.1311	ensur peopl
# 	-2.3703	one could           		2.1255	integr transport
# 	-2.3570	fuel duti           		2.1122	tower hamlet
# 	-2.3564	govern want         		2.0710	major chang
# 	-2.3245	point view          		2.0678	social econom
# 	-2.3059	meet target         		2.0584	ask whether
# 	-2.2815	state govern        		2.0563	intern commun
# 	-2.2802	counti council      		2.0516	inform avail
# 	-2.2776	interest hear       		2.0435	occupi territori
# 	-2.2741	govern account      		2.0325	see benefit
# 	-2.2729	statut book         		2.0252	east london
# 	-2.2647	much hope           		2.0237	govern support
# 	-2.2434	urg minist          		2.0131	suppli chain
# 	-2.2234	hope govern         		2.0123	want thank
# 	-2.2189	huge amount         		2.0092	task forc
# 	-2.2182	govern target       		2.0087	play field
# 	-2.2145	high speed          		2.0072	direct travel
# 	-2.2144	difficult time      		2.0023	militari action
# 	-2.2059	almost everi        		1.9993	govern bodi
# 	-2.2058	conserv believ      		1.9769	death penalti
# 	-2.2006	per annum           		1.9726	said earlier
# 	-2.2002	get wors            		1.9708	state consid
# 	-2.1928	rule law            		1.9644	conserv liber
# 	-2.1838	lord mandelson      		1.9599	crime reduct
# 	-2.1837	press releas        		1.9537	mani year
# 	-2.1768	mental ill          		1.9512	receiv benefit
# 	-2.1755	minist make         		1.9438	school meal
# 	-2.1745	spend much          		1.9415	plan growth
# 	-2.1740	boundari commiss    		1.9326	new member
# 	-2.1693	lucki enough        		1.9221	chang cours
# 	-2.1593	one two             		1.9085	voluntari sector
# 	-2.1498	green deal          		1.9076	chief inspector
# 	-2.1459	cold war            		1.8975	want take
# 	-2.1297	govern one          		1.8920	social justic
# 	-2.1280	special educ        		1.8912	year conserv
# 	-2.1269	shadow minist       		1.8855	energi compani

# %%
elastic_clf.predict_proba(X_test)
# Out:
# array([[ 0.96458298,  0.03541702],
#        [ 0.25061432,  0.74938568],
#        [ 0.46569952,  0.53430048],
#        ...,
#        [ 0.50337894,  0.49662106],
#        [ 0.04627053,  0.95372947],
#        [ 0.80784458,  0.19215542]])

# %%
X_test.shape
# Out:
# (4000, 47800)

# %% [markdown]
# ## Save model to files

# %%
from sklearn.externals import joblib

#joblib.dump(train_vect, "../models/vec_count_ukmedia_23gram_074.joblib")
#joblib.dump(elastic_clf, "../models/clf_elasticnet_ukmedia_23gram_074.joblib")
# Out:
# ['../models/clf_elasticnet_ukmedia_23gram_074.joblib',
#  '../models/clf_elasticnet_ukmedia_23gram_074.joblib_01.npy',
#  '../models/clf_elasticnet_ukmedia_23gram_074.joblib_02.npy',
#  '../models/clf_elasticnet_ukmedia_23gram_074.joblib_03.npy',
#  '../models/clf_elasticnet_ukmedia_23gram_074.joblib_04.npy']

# %%
def get_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top_a = coefs_with_fns[:n]
    top_b = coefs_with_fns[:-(n + 1):-1]
    return top_a, top_b

top_a, top_b = get_most_informative_features(train_vect, elastic_clf, 100)
top_a_df = pd.DataFrame(top_a)
top_a_df.columns = ['coef', 'term']
top_b_df = pd.DataFrame(top_b)
top_b_df.columns = ['coef', 'term']
top_a_df.to_csv('../data/top10_cons_3c.csv', index=False)
top_b_df.to_csv('../data/top10_lab_3c.csv', index=False)
