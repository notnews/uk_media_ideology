# %% [markdown]
# ### Model Text/Political Party:
#
#    a. Go to uk_proceedings_clean_subset.csv and create all bigrams/trigrams that are in more than 10 documents.
#
#    b. Go to roberts_rules and create all bigrams/trigrams
#
#    c. Remove all roberts_rules bigrams/trigrams from uk_proceedings bigrams/trigrams
#
#    d. Use Regularized Logistic Regression or SVM to predict Labour/Conservative using the remaining bigrams/trigrams

# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../uk_proceedings_clean.zip', usecols=['PARTY', 'SPEECH_TEXT'])
df
# Out:
#                             PARTY  \
# 0                          Labour
# 1                    Conservative
# 2                          Labour
# 3                             SPK
# 4                             NaN
# 5                          Labour
# 6                    Conservative
# 7               Liberal Democrats
# 8         Scottish National Party
# 9           Ulster Unionist Party
# 10      Democratic Unionist Party
# 11                            SPK
# 12                            SPK
# 13                            SPK
# 14                            SPK
# 15                            SPK
# 16                            SPK
# 17                   Conservative
# 18                   Conservative
# 19          Ulster Unionist Party
# 20                         Labour
# 21        Scottish National Party
# 22                         Labour
# 23                            SPK
# 24                    Plaid Cymru
# 25                         Labour
# 26                            SPK
# 27                            NaN
# 28                            SPK
# 29                   Conservative
# ...                           ...
# 941152          Liberal Democrats
# 941153                     Labour
# 941154          Liberal Democrats
# 941155                     Labour
# 941156               Conservative
# 941157                     Labour
# 941158               Conservative
# 941159                     Labour
# 941160               Conservative
# 941161                     Labour
# 941162               Conservative
# 941163                     Labour
# 941164                        NaN
# 941165                        SPK
# 941166               Conservative
# 941167                        SPK
# 941168               Conservative
# 941169                     Labour
# 941170                        NaN
# 941171                        SPK
# 941172               Conservative
# 941173                     Labour
# 941174          Liberal Democrats
# 941175               Conservative
# 941176                   Alliance
# 941177  Democratic Unionist Party
# 941178                   Alliance
# 941179                Independent
# 941180                   Alliance
# 941181               Conservative
#
#                                               SPEECH_TEXT
# 0       sir edward truli beauti day sun shine god heav...
# 1       sir edward may say delight back leader interru...
# 2       sir edward sat eight speaker like endors every...
# 3       five year sir edward sinc abl address way firs...
# 4       stand upper step take chair speakerelect wish ...
# 5       madam speakerelect rise congratul secur unanim...
# 6       madam speakerelect delight join prime minist c...
# 7       madam speakerelect give great pleasur behalf b...
# 8       behalf joint scottish nation partyplaid cymru ...
# 9       great pleasur rise endors much said alreadi ex...
# 10      congratul madam speakerelect elect speakership...
# 11      report hous hous peer majesti royal commission...
# 12      must call upon member hous accord usual custom...
# 13      member proceed take oath regret report hous de...
# 14      hope possibl morn member wish take oath affirm...
# 15      may conveni hous indic afternoon shall call up...
# 16      wish make statement avail servic hous take sea...
# 17      point order madam speaker extent assent consul...
# 18      point order madam speaker gave notic would ask...
# 19      point order madam speaker may draw attent appe...
# 20      point order madam speaker former member parlia...
# 21      point order madam speaker hon member halesowen...
# 22      point order madam speaker regard statement mem...
# 23      order could deal one subject time allow come b...
# 24      point order madam speaker spoke leader hous ye...
# 25      point order madam speaker confirm revis proced...
# 26                                              quit true
# 27                                                   rose
# 28                         go take point order shall take
# 29      point order madam speaker accept issu decid ma...
# ...                                                   ...
# 941152                             hon gentleman give way
# 941153        think minist take account point quit import
# 941154  right hon gentleman say would like elig criter...
# 941155  write budget dispatch box even stand record gi...
# 941156                       right hon gentleman give way
# 941157  hon gentleman afternoon third area claim bill ...
# 941158                                               rose
# 941159                   never proper answer hope get one
# 941160  let tell right hon gentleman bill introduc pro...
# 941161  right hon gentleman answer question respons cq...
# 941162  shadow secretari state bandi around big word l...
# 941163  took action address care standard nh right hon...
# 941164                                               rose
# 941165  order go call hon member totn dr wollaston app...
# 941166                                       indic assent
# 941167                            call dr sarah wollaston
# 941168  thank mr speaker congratul secretari state gro...
# 941169  want make one brief point care societi deliv l...
# 941170                                               rose
# 941171  order hon member know sympathet everyon tri he...
# 941172  shall make two brief point think two thing bil...
# 941173  shall brief throughout passag bill felt consid...
# 941174  bill deserv third read replac year piecem dog ...
# 941175  great pleasur present petit sign constitu show...
# 941176  grate opportun abl rais import issu access cle...
# 941177  million peopl poor water qualiti billion peopl...
# 941178  agre hon gentleman say right import water sani...
# 941179  grate hon ladi allow interven import adjourn d...
# 941180  thank hon ladi intervent previou highlevel mee...
# 941181  thank hon member belfast east naomi long call ...
#
# [941182 rows x 2 columns]

# %%
df.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#                                      PARTY
# PARTY
# Alliance                               278
# CWM                                   5709
# Conservative                        336361
# DCWM                                 10996
# Democratic Unionist Party             6014
# Green                                  756
# Independent                           1324
# Independent Conservative                46
# Independent Labour                      44
# Independent Ulster Unionist             89
# Labour                              442763
# Liberal Democrats                    83142
# Plaid Cymru                           5212
# Respect                                122
# SPK                                  18501
# Scottish National Party               9537
# Social Democratic and Labour Party    2297
# Ulster Unionist Party                 4087
# United Kingdom Independence Party      107
# United Kingdom Unionist Party          282

# %%
sdf = df[df.PARTY.isin(['Labour', 'Conservative']) & df.SPEECH_TEXT.notnull()]

# %%
sdf.loc[:, 'textlen'] = sdf.loc[:, 'SPEECH_TEXT'].apply(lambda c: len(c))
# Out:
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /opt/venv/local/lib/python2.7/site-packages/pandas/core/indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
sdf = sdf[sdf.textlen >= 2000]

# %%
sdf.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#               PARTY
# PARTY
# Conservative  22299
# Labour        27301

# %%
import random

def RandomSample(data, size):
    """Returns random sample for given size
       If training data set is too big, we can reduce its size
    """
    return data.ix[random.sample(data.index, size)]


def StratifiedSample(data, nperlabel, label='label'):
    """Returns stratified data with N per label
    """
    sample = pd.DataFrame()
    datagrp = data.groupby(label)
    sortedgrp = datagrp.size().sort_values(ascending=False)
    for i, l in enumerate(sortedgrp.index):
        if sortedgrp[l] > nperlabel:
            print("==> %-50s %6d" % (l, sortedgrp[l]))
            sample = sample.append(RandomSample(data[data[label] == l],
                                   nperlabel))
        else:
            break
    print("There are %d labels have more than %d articles" % (i + 1, nperlabel))
    print("Sample size: %s articles" % (len(sample)))
    return sample

# %%
N_PER_LABEL = 10000

subset = StratifiedSample(sdf, N_PER_LABEL, 'PARTY')
# Out:
# ==> Labour                                              27301
# ==> Conservative                                        22299
# There are 2 labels have more than 10000 articles
# Sample size: 20000 articles

# %%
subset
# Out:
#                PARTY                                        SPEECH_TEXT  \
# 286202        Labour  think hon ladi find professor stewart restrict...
# 219126        Labour  grate chanc discuss nuffield report teach fore...
# 397804        Labour  permiss mr speaker would like make statement d...
# 180160        Labour  term strict word bill answer ye howev term ind...
# 281188        Labour  perfectli awar statement hon friend draw atten...
# 141670        Labour  worthwhil debat enabl right hon friend secreta...
# 904269        Labour  sure hon gentleman know take issu serious seen...
# 164640        Labour  hous rare heard meaner speech one made hon mem...
# 366266        Labour  add warmest congratul hon friend member west r...
# 426549        Labour  made point earlier accept hon gentleman say mu...
# 573470        Labour  confess although substanti person vote singleh...
# 545169        Labour  promis briefer hon member arundel south down n...
# 595516        Labour  go drawn argument beatl know right hon gentlem...
# 602542        Labour  welcom bill cours express normal caution conse...
# 379192        Labour  grate hon gentleman draw hous attent mine repo...
# 736010        Labour  beg move hous note alarm recent evid show four...
# 154788        Labour  hon friend make interest analog bill spread lo...
# 276253        Labour  welcom chanc contribut howev briefli debat hon...
# 56823         Labour  give way shall deal detail report european mon...
# 487197        Labour  glad opportun respond hon gentleman question i...
# 397369        Labour  differ bill debat impact happen word put legis...
# 367790        Labour  welcom bill introduc hon member canterburi mr ...
# 341515        Labour  beg move leav hous end question add instead th...
# 558907        Labour  brief debat focu tragic death one critic error...
# 556887        Labour  pleasur follow hon member north cornwal dan ro...
# 24659         Labour  good debat although hous well attend debat eur...
# 583966        Labour  hon gentleman would recognis listen said work ...
# 119839        Labour  agre much said side argument find labour membe...
# 125487        Labour  glad hon member south staffordshir sir p corma...
# 579904        Labour  larg chunk educ receiv hand jesuit alway taugh...
# ...              ...                                                ...
# 553259  Conservative  right hon friend hit head differ labour way co...
# 606466  Conservative  robert kagan write world return normal author ...
# 401961  Conservative  fundament premis right hon friend comment mora...
# 654006  Conservative  fact sever outstand speech includ one hon frie...
# 916290  Conservative  madam deputi speaker pleasur speak chairmanshi...
# 776956  Conservative  congratul hon friend member hast rye amber rud...
# 171043  Conservative  ye past two month sinc start job opposit defen...
# 567774  Conservative  thank home secretari advanc sight statement gl...
# 534605  Conservative  grate opportun come hous rais import issu cons...
# 801227  Conservative  shame madam deputi speaker long list thing rel...
# 727169  Conservative  consciou time short number colleagu wish speak...
# 746727  Conservative  thank hon member liverpool west derbi stephen ...
# 68770   Conservative  welcom debat congratul hon member blaenau gwen...
# 142411  Conservative  hon gentleman claim never blabi must tell neig...
# 66006   Conservative  shall endeavour speak briefli good debat pay t...
# 174224  Conservative  beg move leav given bring bill requir retail a...
# 3849    Conservative  mr deputi speaker delight see chair thank call...
# 845762  Conservative  complex controversi issu huge import constitu ...
# 936770  Conservative  concur entir hon friend demand offic busi time...
# 295585  Conservative  welcom opportun debat resolut fact foreign sec...
# 706123  Conservative  declar interest debat wife serv naval offic ca...
# 146411  Conservative  fascin debat began secretari state introduc bi...
# 403324  Conservative  good fortun opportun debat subject diabet mini...
# 615622  Conservative  delight abl catch eye debat madam deputi speak...
# 852324  Conservative  congratul hon friend member newton abbot ann m...
# 287716  Conservative  beg move hous express sympathi pupil parent te...
# 790275  Conservative  ultim clinicianwhich frankli minist must say p...
# 124333  Conservative  would problem suggest govern would gone conser...
# 394006  Conservative  behalf opposit welcom bill sinc announc lord l...
# 557230  Conservative  hon gentleman behav give chanc interven toward...
#
#         textlen
# 286202     9353
# 219126     7089
# 397804     4463
# 180160     4840
# 281188     2922
# 141670     4349
# 904269     2571
# 164640     2162
# 366266     2230
# 426549     2925
# 573470     3213
# 545169     4589
# 595516     3196
# 602542     5764
# 379192     4026
# 736010     3483
# 154788     2103
# 276253     4731
# 56823      2326
# 487197     2196
# 397369    11928
# 367790     3763
# 341515     3487
# 558907     6795
# 556887     5869
# 24659      3303
# 583966     2469
# 119839     2704
# 125487     3720
# 579904     2141
# ...         ...
# 553259     2419
# 606466     4049
# 401961     2020
# 654006     4071
# 916290     4998
# 776956     3281
# 171043     2073
# 567774     2649
# 534605     6300
# 801227     2440
# 727169     2278
# 746727     8999
# 68770      2575
# 142411     3132
# 66006      3320
# 174224     2572
# 3849       6558
# 845762     2116
# 936770     2311
# 295585     2554
# 706123     3122
# 146411     4360
# 403324     3611
# 615622     5113
# 852324     2505
# 287716     3618
# 790275     3231
# 124333     2335
# 394006     2622
# 557230     2165
#
# [20000 rows x 3 columns]

# %%
#subset.to_csv('/tmp/subset.csv.gz', compression='gzip', index=False)

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(subset.SPEECH_TEXT, subset.PARTY, test_size=0.2, random_state=42)

# %%
#all_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10)
#all_vect = CountVectorizer(ngram_range=(2, 3), min_df=10)
all_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, stop_words=['friend', 'member', 'hon', 'ladi', 'gentleman'])
all_vect.fit(X_train.astype(str))
vocab = []
i = 0
for a in all_vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 2477
# Total 132607

# %%
#train_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10, vocabulary=vocab)
#train_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=vocab)
train_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=vocab, stop_words=['friend', 'member', 'hon', 'ladi', 'gentleman'])

# %%
X_train = train_vect.transform(X_train.astype(str))
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = train_vect.transform(X_test.astype(str))
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
from sklearn.linear_model import SGDClassifier

elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
t0 = time.time()
elastic_clf.fit(X_train, y_train)
t1 = time.time()
prediction_elastic = elastic_clf.predict(X_test)
t2 = time.time()
time_elastic_train = t1-t0
time_elastic_predict = t2-t1

print("Results for Elastic Net")
print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
print(classification_report(y_test, prediction_elastic))
# Out:
# Results for Elastic Net
# Training time: 17.344430s; Prediction time: 0.005730s
#              precision    recall  f1-score   support
#
# Conservative       0.76      0.77      0.77      1981
#      Labour       0.78      0.76      0.77      2019
#
# avg / total       0.77      0.77      0.77      4000

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print "\t%.4f\t%-20s\t\t%.4f\t%-20s" % (coef_1, fn_1, coef_2, fn_2)

# %%
show_most_informative_features(train_vect, elastic_clf, 100)
# Out:
# 	-7.6254	secretari state     		8.7919	right secretari
# 	-5.1908	labour parti        		8.7244	right secretari state
# 	-4.8900	financi secretari   		6.8433	right minist
# 	-4.4804	hope minist         		5.5866	right home secretari
# 	-4.2001	offici report       		5.5717	right home
# 	-3.9866	minist said         		5.1739	conserv parti
# 	-3.8865	coalit govern       		4.4298	right chancellor
# 	-3.6495	new labour          		4.4171	tori govern
# 	-3.6122	hous adjourn        		4.3458	amend no
# 	-3.5988	paymast gener       		4.1364	tori parti
# 	-3.3071	minist know         		4.1152	right prime
# 	-3.2794	perhap minist       		4.0966	right prime minist
# 	-3.2434	red book            		3.8673	right foreign
# 	-3.2359	econom secretari    		3.7398	right foreign secretari
# 	-3.2077	agre hous           		3.2768	way forward
# 	-3.1959	govern fail         		3.2377	trade union
# 	-3.1528	red tape            		3.1656	south wale
# 	-3.1517	hear minist         		3.0603	busi secretari
# 	-3.1376	agre hous adjourn   		2.9981	develop countri
# 	-3.1376	put agre hous       		2.8947	public servic
# 	-3.1340	would like          		2.8500	adjourn accordingli
# 	-3.1217	govern seem         		2.8483	agre adjourn
# 	-3.0641	prime minist        		2.8175	agre adjourn accordingli
# 	-3.0180	way govern          		2.8098	put agre adjourn
# 	-3.0030	commun hospit       		2.8077	work peopl
# 	-2.9626	right leader opposit		2.7028	right deputi prime
# 	-2.9171	home secretari      		2.6900	right leader hous
# 	-2.8886	one two             		2.6787	right deputi
# 	-2.8058	last govern         		2.6469	hous benefit
# 	-2.7806	public financ       		2.5771	bedroom tax
# 	-2.7432	minist agre         		2.5608	energi compani
# 	-2.7313	sure minist         		2.5573	previou administr
# 	-2.7112	go wrong            		2.5523	bill provid
# 	-2.6974	minist may          		2.5509	nation assembl
# 	-2.6807	pleasur follow      		2.5237	news intern
# 	-2.6187	declar interest     		2.5221	new technolog
# 	-2.6108	good point          		2.5208	south yorkshir
# 	-2.5894	govern say          		2.4635	secur debat
# 	-2.5534	much hope           		2.4617	labour govern
# 	-2.5520	minist would        		2.4241	issu rais
# 	-2.5462	side hous           		2.3671	job growth
# 	-2.4997	minist give         		2.3607	new deal
# 	-2.4826	grate minist        		2.3472	peopl work
# 	-2.4740	increas tax         		2.3402	earlyday motion
# 	-2.4653	one thing           		2.3366	disabl peopl
# 	-2.4650	chancellor exchequ  		2.3329	tax cut
# 	-2.4330	british peopl       		2.2943	greater manchest
# 	-2.4104	chief secretari     		2.2738	nelson mandela
# 	-2.3823	absolut right       		2.2690	sustain develop
# 	-2.3495	district council    		2.2534	welcom bill
# 	-2.3430	written answer      		2.2531	council hous
# 	-2.3367	one could           		2.2530	poll tax
# 	-2.3285	govern may          		2.2478	scottish execut
# 	-2.3273	howev govern        		2.2454	probat servic
# 	-2.3241	yet anoth           		2.2342	cut public
# 	-2.2884	govern want         		2.1973	human right
# 	-2.2805	rural area          		2.1547	west bromwich
# 	-2.2693	nation interest     		2.1230	steel industri
# 	-2.2584	deputi speaker      		2.1123	social exclus
# 	-2.2541	minist state        		2.0783	high standard
# 	-2.2424	european court      		2.0679	afford hous
# 	-2.2297	part bill           		2.0644	work togeth
# 	-2.2281	none less           		2.0637	rais standard
# 	-2.2278	group amend         		2.0609	shadow chancellor
# 	-2.2225	urg govern          		2.0609	pension scheme
# 	-2.2111	polit correct       		2.0391	ask whether
# 	-2.2057	shadow minist       		2.0332	pension poverti
# 	-2.1601	polic forc          		2.0297	tower hamlet
# 	-2.1555	one might           		1.9869	world bank
# 	-2.1437	question minist     		1.9857	deal issu
# 	-2.1317	bill minist         		1.9821	young peopl
# 	-2.1271	part govern         		1.9760	spend cut
# 	-2.1245	minist awar         		1.9614	everi child
# 	-2.1216	state said          		1.9580	move forward
# 	-2.1176	milton keyn         		1.9395	tee valley
# 	-2.1025	hold govern         		1.9200	climat chang
# 	-2.0874	must ask            		1.9197	take forward
# 	-2.0741	common ground       		1.9081	limit liabil
# 	-2.0724	equit life          		1.9008	vest interest
# 	-2.0641	right birkenhead    		1.8816	doubledip recess
# 	-2.0633	minist say          		1.8813	ask right
# 	-2.0344	secretari state said		1.8781	child care
# 	-2.0296	regist interest     		1.8750	meet need
# 	-2.0207	free trade          		1.8744	state pension
# 	-2.0138	need know           		1.8625	opposit parti
# 	-2.0101	one need            		1.8482	made clear
# 	-2.0041	famili court        		1.8455	enabl us
# 	-1.9978	rule law            		1.8391	later year
# 	-1.9754	taxpay money        		1.8375	food bank
# 	-1.9634	wind farm           		1.8367	death penalti
# 	-1.9633	west sussex         		1.8239	good practic
# 	-1.9437	meanstest benefit   		1.8225	north wale
# 	-1.9374	tax increas         		1.8207	work pay
# 	-1.9313	pension fund        		1.8100	welcom propos
# 	-1.9285	world servic        		1.8082	iraqi peopl
# 	-1.9284	import subject      		1.7990	ground rent
# 	-1.9239	mr speaker          		1.7884	local govern
# 	-1.9225	cold war            		1.7868	new hospit
# 	-1.9204	govern claim        		1.7842	welsh offic
# 	-1.9196	one would           		1.7838	health centr

# %%
elastic_clf.predict_proba(X_test)
# Out:
# array([[ 0.87373131,  0.12626869],
#        [ 0.48098852,  0.51901148],
#        [ 0.30823505,  0.69176495],
#        ...,
#        [ 0.52484475,  0.47515525],
#        [ 0.35799884,  0.64200116],
#        [ 0.50084232,  0.49915768]])

# %%
X_test.shape
# Out:
# (4000, 132607)

# %% [markdown]
# ## Save model to files

# %%
from sklearn.externals import joblib

#joblib.dump(train_vect, "../models/vec_count_23gram_077.joblib")
#joblib.dump(elastic_clf, "../models/clf_elasticnet_077.joblib")
# Out:
# ['../models/clf_elasticnet_077.joblib',
#  '../models/clf_elasticnet_077.joblib_01.npy',
#  '../models/clf_elasticnet_077.joblib_02.npy',
#  '../models/clf_elasticnet_077.joblib_03.npy',
#  '../models/clf_elasticnet_077.joblib_04.npy']

# %%
def get_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top_a = coefs_with_fns[:n]
    top_b = coefs_with_fns[:-(n + 1):-1]
    return top_a, top_b

top_a, top_b = get_most_informative_features(train_vect, elastic_clf, 100)
top_a_df = pd.DataFrame(top_a)
top_a_df.columns = ['coef', 'term']
top_b_df = pd.DataFrame(top_b)
top_b_df.columns = ['coef', 'term']
top_a_df.to_csv('../data/top10_cons_3a.csv', index=False)
top_b_df.to_csv('../data/top10_lab_3a.csv', index=False)
