# %% [markdown]
# 10. Predict news data
# 11. Output CSV with 3 cols of news data: news_source, pred_cons, date

# %%
import pandas as pd
import numpy as np
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfTransformer

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
vect_name = '../models/vec_count_23gram_081.joblib'
clf_name = '../models/clf_elasticnet_081.joblib'

# %%
vect = joblib.load(vect_name)
clf = joblib.load(clf_name)

# %%
len(vect.vocabulary_)
# Out:
# 137093

# %%
df = pd.read_csv('../media_text/uk_media_clean_deduped_201x_gt1k.csv', usecols=['pubDate', 'src_name', 'text'])
df
# Out:
#                      pubDate  \
# 0        2010-04-13 00:00:00
# 1        2011-06-21 00:00:00
# 2        2013-03-19 00:00:00
# 3        2014-05-12 00:00:00
# 4        2012-08-08 00:00:00
# 5        2013-06-12 00:00:00
# 6        2012-02-27 03:18:00
# 7        2012-06-14 00:00:00
# 8        2010-04-28 16:16:00
# 9        2010-06-04 08:27:00
# 10       2010-09-07 00:00:00
# 11       2010-01-04 07:41:00
# 12       2015-01-05 00:00:00
# 13       2011-02-08 00:00:00
# 14       2013-08-02 00:00:00
# 15       2010-06-16 01:58:00
# 16       2014-06-09 00:00:00
# 17       2013-11-24 00:00:00
# 18       2012-08-11 00:00:00
# 19       2012-09-10 18:00:00
# 20       2010-11-27 00:00:00
# 21       2014-08-14 00:00:00
# 22       2010-02-23 00:00:00
# 23       2014-06-05 00:00:00
# 24       2011-02-01 07:07:00
# 25       2013-05-18 00:00:00
# 26       2010-04-05 00:00:00
# 27       2013-06-17 00:00:00
# 28       2010-05-11 00:00:00
# 29       2013-06-20 00:00:00
# ...                      ...
# 2742705  2013-12-12 00:00:00
# 2742706  2013-04-28 00:00:00
# 2742707  2011-08-05 07:25:00
# 2742708  2014-03-30 00:00:00
# 2742709  2010-08-06 02:56:00
# 2742710  2010-01-04 01:05:00
# 2742711  2011-04-12 00:00:00
# 2742712  2011-07-11 00:00:00
# 2742713  2013-03-19 00:00:00
# 2742714  2011-02-13 00:00:00
# 2742715  2014-04-04 00:00:00
# 2742716  2011-07-28 00:00:00
# 2742717  2013-06-26 00:00:00
# 2742718  2011-08-01 00:00:00
# 2742719  2010-08-19 08:49:00
# 2742720  2010-12-14 12:57:00
# 2742721  2012-04-27 00:00:00
# 2742722  2010-02-26 00:00:00
# 2742723  2012-04-19 00:00:00
# 2742724  2013-08-09 00:00:00
# 2742725  2010-03-02 08:48:00
# 2742726  2010-05-17 04:57:00
# 2742727  2012-01-31 00:00:00
# 2742728  2013-04-10 00:00:00
# 2742729  2013-08-01 00:00:00
# 2742730  2011-05-12 00:00:00
# 2742731  2013-06-27 00:00:00
# 2742732  2014-06-03 00:00:00
# 2742733  2014-03-21 00:00:00
# 2742734  2014-10-16 00:00:00
#
#                                                       text  \
# 0        fundrais prepar rise challeng power walk chall...
# 1        powerteam secur deal windfarm staff report tue...
# 2        former england star peter shilton ban road adm...
# 3        debo adewumi secretari nigerian commun waltham...
# 4        leav court dr luci dawson got sick pay one hos...
# 29                                this is exeter
# ...                                          ...
# 2742705                         the press (york)
# 2742706                               eubusiness
# 2742707                             barnet times
# 2742708                                  skynews
# 2742709                              bolton news
# 2742710                                  ananova
# 2742711                        belfast telegraph
# 2742712                                  ananova
# 2742713                          hull daily mail
# 2742714                      the daily telegraph
# 2742715  southern daily echo - this is hampshire
# 2742716            borehamwood and elstree times
# 2742717             bradford telegraph and argus
# 2742718            borehamwood and elstree times
# 2742719                              bolton news
# 2742720                          banbridge today
# 2742721                            belfast today
# 2742722                        belfast telegraph
# 2742723              retford trader and guardian
# 2742724                  this is gloucestershire
# 2742725                       chingford guardian
# 2742726                        buxton advertiser
# 2742727  southern daily echo - this is hampshire
# 2742728                         cornish guardian
# 2742729                          plymouth herald
# 2742730                        belfast telegraph
# 2742731              harlow citizen and guardian
# 2742732                         express and star
# 2742733                     lancashire telegraph
# 2742734                             royston crow
#
# [2742735 rows x 3 columns]

# %%
X = vect.transform(df.text.astype(str))

# %%
X.shape
# Out:
# (2742735, 137093)

# %%
tfidf = TfidfTransformer()
X = tfidf.fit_transform(X)

# %%
X.shape
# Out:
# (2742735, 137093)

# %%
y_pred = clf.predict(X)

# %%
y_pred.shape
# Out:
# (2742735,)

# %%
X_proba = clf.predict_proba(X)

# %%
X_proba
# Out:
# array([[ 0.57818988,  0.42181012],
#        [ 0.31266354,  0.68733646],
#        [ 0.55197893,  0.44802107],
#        ...,
#        [ 0.33712666,  0.66287334],
#        [ 0.62666108,  0.37333892],
#        [ 0.37943545,  0.62056455]])

# %%
proba_cons = X_proba[:,0]

# %%
df['predicted'] = y_pred
df['pred_cons'] = proba_cons
df
# Out:
#                      pubDate  \
# 0        2010-04-13 00:00:00
# 1        2011-06-21 00:00:00
# 2        2013-03-19 00:00:00
# 3        2014-05-12 00:00:00
# 4        2012-08-08 00:00:00
# 5        2013-06-12 00:00:00
# 6        2012-02-27 03:18:00
# 7        2012-06-14 00:00:00
# 8        2010-04-28 16:16:00
# 9        2010-06-04 08:27:00
# 10       2010-09-07 00:00:00
# 11       2010-01-04 07:41:00
# 12       2015-01-05 00:00:00
# 13       2011-02-08 00:00:00
# 14       2013-08-02 00:00:00
# 15       2010-06-16 01:58:00
# 16       2014-06-09 00:00:00
# 17       2013-11-24 00:00:00
# 18       2012-08-11 00:00:00
# 19       2012-09-10 18:00:00
# 20       2010-11-27 00:00:00
# 21       2014-08-14 00:00:00
# 22       2010-02-23 00:00:00
# 23       2014-06-05 00:00:00
# 24       2011-02-01 07:07:00
# 25       2013-05-18 00:00:00
# 26       2010-04-05 00:00:00
# 27       2013-06-17 00:00:00
# 28       2010-05-11 00:00:00
# 29       2013-06-20 00:00:00
# ...                      ...
# 2742705  2013-12-12 00:00:00
# 2742706  2013-04-28 00:00:00
# 2742707  2011-08-05 07:25:00
# 2742708  2014-03-30 00:00:00
# 2742709  2010-08-06 02:56:00
# 2742710  2010-01-04 01:05:00
# 2742711  2011-04-12 00:00:00
# 2742712  2011-07-11 00:00:00
# 2742713  2013-03-19 00:00:00
# 2742714  2011-02-13 00:00:00
# 2742715  2014-04-04 00:00:00
# 2742716  2011-07-28 00:00:00
# 2742717  2013-06-26 00:00:00
# 2742718  2011-08-01 00:00:00
# 2742719  2010-08-19 08:49:00
# 2742720  2010-12-14 12:57:00
# 2742721  2012-04-27 00:00:00
#
#                                         src_name     predicted  pred_cons
# 0                            southern daily echo  Conservative   0.578190
# 1                              belfast telegraph        Labour   0.312664
# 2                                essex chronicle  Conservative   0.551979
# 3                             chingford guardian        Labour   0.362759
# 4                                 the daily mail        Labour   0.321160
# 5                               cornish guardian  Conservative   0.540253
# 6                            ilkeston advertiser  Conservative   0.572750
# 7                           east lothian courier        Labour   0.342616
# 8                               banbury guardian  Conservative   0.624551
# 9                         cambridge evening news        Labour   0.492244
# 10                           southern daily echo  Conservative   0.655492
# 11                              ballymoney today        Labour   0.473753
# 12               international business times uk  Conservative   0.573171
# 13                                the daily mail        Labour   0.418010
# 14                               plymouth herald        Labour   0.326685
# 15                              reuters alertnet        Labour   0.499739
# 16                           eastern daily press  Conservative   0.616034
# 17                 herald scotland breaking news        Labour   0.479976
# 18                               hull daily mail        Labour   0.471470
# 19                peterborough evening telegraph  Conservative   0.633809
# 20                              ballymoney today  Conservative   0.593965
# 21            wiltshire news / this is wiltshire  Conservative   0.572576
# 22                           southern daily echo        Labour   0.496955
# 23                                    daily post        Labour   0.461227
# 24                                   bolton news        Labour   0.332423
# 25                               essex chronicle        Labour   0.493556
# 26                           southern daily echo        Labour   0.354291
# 27                              bucks free press        Labour   0.360806
# 28                           southern daily echo  Conservative   0.564649
# 29                                this is exeter  Conservative   0.518635
# ...                                          ...           ...        ...
# 2742705                         the press (york)        Labour   0.435525
# 2742706                               eubusiness        Labour   0.369103
# 2742707                             barnet times  Conservative   0.556581
# 2742708                                  skynews  Conservative   0.768641
# 2742709                              bolton news        Labour   0.445980
# 2742710                                  ananova        Labour   0.182918
# 2742711                        belfast telegraph        Labour   0.324656
# 2742712                                  ananova        Labour   0.482815
# 2742713                          hull daily mail  Conservative   0.502903
# 2742714                      the daily telegraph        Labour   0.305752
# 2742715  southern daily echo - this is hampshire  Conservative   0.799789
# 2742716            borehamwood and elstree times        Labour   0.473892
# 2742717             bradford telegraph and argus  Conservative   0.559479
# 2742718            borehamwood and elstree times        Labour   0.459031
# 2742719                              bolton news  Conservative   0.538309
# 2742720                          banbridge today        Labour   0.425724
# 2742721                            belfast today  Conservative   0.565435
# 2742722                        belfast telegraph  Conservative   0.508648
# 2742723              retford trader and guardian  Conservative   0.511925
# 2742724                  this is gloucestershire  Conservative   0.655266
# 2742725                       chingford guardian        Labour   0.421589
# 2742726                        buxton advertiser  Conservative   0.525706
# 2742727  southern daily echo - this is hampshire        Labour   0.427987
# 2742728                         cornish guardian        Labour   0.493128
# 2742729                          plymouth herald  Conservative   0.571582
# 2742730                        belfast telegraph  Conservative   0.526897
# 2742731              harlow citizen and guardian        Labour   0.436010
# 2742732                         express and star        Labour   0.337127
# 2742733                     lancashire telegraph  Conservative   0.626661
# 2742734                             royston crow        Labour   0.379435
#
# [2742735 rows x 5 columns]

# %%
df.columns
# Out:
# Index([u'pubDate', u'text', u'src_name', u'predicted', u'pred_cons'], dtype='object')

# %%
df.columns = ['date', 'text', 'news_source', 'predicted', 'pred_cons']
#df.to_csv('../data/uk_media_prediction_1.csv', index=False, columns=['date', 'news_source', 'pred_cons'])

# %%
sdf = df.groupby('news_source').agg({'pred_cons': np.mean})
sdf.reset_index(inplace=True)

# %%
sdf.columns = ['news_source', 'pred_cons']
sdf
# Out:
#                             news_source  pred_cons
# 0                                24dash   0.363675
# 1                  a world to win blogs   0.481059
# 2                          agra-net.com   0.494556
# 3                             alert net   0.490065
# 4         alliance for workers' liberty   0.434548
# 5                               ananova   0.486413
# 6                 ananova - orange news   0.487675
# 7                    andover advertiser   0.491671
# 8                       asharq al-awsat   0.508221
# 9                         ayrshire post   0.443086
# 10                    bakery and snacks   0.436977
# 11                   ballyclare gazette   0.480642
# 12                      ballymena today   0.462557
# 13                     ballymoney today   0.476489
# 14                     banbridge leader   0.476223
# 15                      banbridge today   0.476615
# 16                     banbury guardian   0.485011
# 17            barking and dagenham post   0.472149
# 18                  barnesley chronicle   0.478985
# 19                         barnet times   0.475518
# 20                  basingstoke gazette   0.494060
# 21                 bbc - leicester news   0.495848
# 22                        bbc news - uk   0.476566
# 23                      bbc news europe   0.479796
# 24           beccles and bungay journal   0.493888
# 25            bedford times and citizen   0.488072
# 26                        bedford today   0.487275
# 27                        belfast media   0.453224
# 28                    belfast telegraph   0.480650
# 29                        belfast today   0.471804
# ..                                  ...        ...
# 225               the herald (scotland)   0.470453
# 226                  the independent uk   0.481970
# 227                   the northern echo   0.467563
# 228                   the pig site - uk   0.428217
# 229                    the press (york)   0.496274
# 230               the press and journal   0.472535
# 231               the reading chronicle   0.444250
# 232                        the scotsman   0.461524
# 233                    this is cheshire   0.484268
# 234                      this is exeter   0.496606
# 235             this is gloucestershire   0.483903
# 236                      times and star   0.469750
# 237                        tyrone times   0.454703
# 238                 uk uncut on twitter   0.492375
# 239             waltham forest guardian   0.411676
# 240                 wandsworth guardian   0.480133
# 241      wanstead and woodford guardian   0.472935
# 242            west sussex county times   0.516177
# 243                        western mail   0.465631
# 244                               wharf   0.437090
# 245  wiltshire news / this is wiltshire   0.492960
# 246                        wirral globe   0.460665
# 247                    wisbech standard   0.476627
# 248                     wokingham times   0.483557
# 249                      worcester news   0.486610
# 250                    worksop guardian   0.477735
# 251                  world nuclear news   0.452448
# 252                     worthing herald   0.503249
# 253              yorkshire evening post   0.472707
# 254                      yorkshire post   0.460935
#
# [255 rows x 2 columns]

# %%
sdf[sdf.pred_cons >= 0.5]
# Out:
#                       news_source  pred_cons
# 8                 asharq al-awsat   0.508221
# 32                  bexhill today   0.500500
# 37          bognor regis observer   0.521154
# 38                   bognor today   0.513517
# 46         brighton evening argus   0.510365
# 48               bucks free press   0.518941
# 49                   bucks herald   0.508477
# 65            chichester observer   0.515214
# 71                   country life   0.519117
# 83                   diss mercury   0.523053
# 86       driffield times and post   0.507315
# 87               dunmow broadcast   0.536566
# 89            eastern daily press   0.533996
# 91   echo - essex news and sports   0.507211
# 96                     eubusiness   0.549047
# 109                grantham today   0.509301
# 119         hemel hempstead today   0.504939
# 126             horticulture week   0.563479
# 138    isle of wight county press   0.586646
# 140        kenilworth weekly news   0.500636
# 151                  louth leader   0.501897
# 154                     lynn news   0.511940
# 164                 newbury today   0.504359
# 181                   oxford mail   0.500329
# 189      redhill and reigate life   0.505698
# 197       saffron walden reporter   0.525790
# 203       somerset county gazette   0.510262
# 207             spalding guardian   0.504930
# 208              stamford mercury   0.501549
# 211             surrey advertiser   0.500305
# 213                  telegraph uk   0.508743
# 218                the daily mail   0.508676
# 242      west sussex county times   0.516177
# 252               worthing herald   0.503249
