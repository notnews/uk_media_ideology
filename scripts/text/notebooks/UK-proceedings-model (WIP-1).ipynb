# %% [markdown]
# ### Model Text/Political Party:
#
#    a. Go to uk_proceedings_clean_subset.csv and create all bigrams/trigrams that are in more than 10 documents.
#
#    b. Go to roberts_rules and create all bigrams/trigrams
#
#    c. Remove all roberts_rules bigrams/trigrams from uk_proceedings bigrams/trigrams
#
#    d. Use Regularized Logistic Regression or SVM to predict Labour/Conservative using the remaining bigrams/trigrams

# %%
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../uk_proceedings_clean.zip', usecols=['PARTY', 'SPEECH_TEXT'])
df
# Out:
#                             PARTY  \
# 0                          Labour
# 1                    Conservative
# 2                          Labour
# 3                             SPK
# 4                             NaN
# 5                          Labour
# 6                    Conservative
# 7               Liberal Democrats
# 8         Scottish National Party
# 9           Ulster Unionist Party
# 10      Democratic Unionist Party
# 11                            SPK
# 12                            SPK
# 13                            SPK
# 14                            SPK
# 15                            SPK
# 16                            SPK
# 17                   Conservative
# 18                   Conservative
# 19          Ulster Unionist Party
# 20                         Labour
# 21        Scottish National Party
# 22                         Labour
# 23                            SPK
# 24                    Plaid Cymru
# 25                         Labour
# 26                            SPK
# 27                            NaN
# 28                            SPK
# 29                   Conservative
# ...                           ...
# 941152          Liberal Democrats
# 941153                     Labour
# 941154          Liberal Democrats
# 941155                     Labour
# 941156               Conservative
# 941157                     Labour
# 941158               Conservative
# 941159                     Labour
# 941160               Conservative
# 941161                     Labour
# 941162               Conservative
# 941163                     Labour
# 941164                        NaN
# 941165                        SPK
# 941166               Conservative
# 941167                        SPK
# 941168               Conservative
# 941169                     Labour
# 941170                        NaN
# 941171                        SPK
# 941172               Conservative
# 941173                     Labour
# 941174          Liberal Democrats
# 941175               Conservative
# 941176                   Alliance
# 941177  Democratic Unionist Party
# 941178                   Alliance
# 941179                Independent
# 941180                   Alliance
# 941181               Conservative
#
#                                               SPEECH_TEXT
# 0       sir edward truli beauti day sun shine god heav...
# 1       sir edward may say delight back leader interru...
# 2       sir edward sat eight speaker like endors every...
# 3       five year sir edward sinc abl address way firs...
# 4       stand upper step take chair speakerelect wish ...
# 5       madam speakerelect rise congratul secur unanim...
# 6       madam speakerelect delight join prime minist c...
# 7       madam speakerelect give great pleasur behalf b...
# 8       behalf joint scottish nation partyplaid cymru ...
# 9       great pleasur rise endors much said alreadi ex...
# 10      congratul madam speakerelect elect speakership...
# 11      report hous hous peer majesti royal commission...
# 12      must call upon member hous accord usual custom...
# 13      member proceed take oath regret report hous de...
# 14      hope possibl morn member wish take oath affirm...
# 15      may conveni hous indic afternoon shall call up...
# 16      wish make statement avail servic hous take sea...
# 17      point order madam speaker extent assent consul...
# 18      point order madam speaker gave notic would ask...
# 19      point order madam speaker may draw attent appe...
# 20      point order madam speaker former member parlia...
# 21      point order madam speaker hon member halesowen...
# 22      point order madam speaker regard statement mem...
# 23      order could deal one subject time allow come b...
# 24      point order madam speaker spoke leader hous ye...
# 25      point order madam speaker confirm revis proced...
# 26                                              quit true
# 27                                                   rose
# 28                         go take point order shall take
# 29      point order madam speaker accept issu decid ma...
# ...                                                   ...
# 941152                             hon gentleman give way
# 941153        think minist take account point quit import
# 941154  right hon gentleman say would like elig criter...
# 941155  write budget dispatch box even stand record gi...
# 941156                       right hon gentleman give way
# 941157  hon gentleman afternoon third area claim bill ...
# 941158                                               rose
# 941159                   never proper answer hope get one
# 941160  let tell right hon gentleman bill introduc pro...
# 941161  right hon gentleman answer question respons cq...
# 941162  shadow secretari state bandi around big word l...
# 941163  took action address care standard nh right hon...
# 941164                                               rose
# 941165  order go call hon member totn dr wollaston app...
# 941166                                       indic assent
# 941167                            call dr sarah wollaston
# 941168  thank mr speaker congratul secretari state gro...
# 941169  want make one brief point care societi deliv l...
# 941170                                               rose
# 941171  order hon member know sympathet everyon tri he...
# 941172  shall make two brief point think two thing bil...
# 941173  shall brief throughout passag bill felt consid...
# 941174  bill deserv third read replac year piecem dog ...
# 941175  great pleasur present petit sign constitu show...
# 941176  grate opportun abl rais import issu access cle...
# 941177  million peopl poor water qualiti billion peopl...
# 941178  agre hon gentleman say right import water sani...
# 941179  grate hon ladi allow interven import adjourn d...
# 941180  thank hon ladi intervent previou highlevel mee...
# 941181  thank hon member belfast east naomi long call ...
#
# [941182 rows x 2 columns]

# %%
df.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#                                      PARTY
# PARTY
# Alliance                               278
# CWM                                   5709
# Conservative                        336361
# DCWM                                 10996
# Democratic Unionist Party             6014
# Green                                  756
# Independent                           1324
# Independent Conservative                46
# Independent Labour                      44
# Independent Ulster Unionist             89
# Labour                              442763
# Liberal Democrats                    83142
# Plaid Cymru                           5212
# Respect                                122
# SPK                                  18501
# Scottish National Party               9537
# Social Democratic and Labour Party    2297
# Ulster Unionist Party                 4087
# United Kingdom Independence Party      107
# United Kingdom Unionist Party          282

# %%
sdf = df[df.PARTY.isin(['Labour', 'Conservative']) & df.SPEECH_TEXT.notnull() & (df.SPEECH_TEXT.str.len() >= 2000)]

# %%
sdf.groupby('PARTY').agg({'PARTY': 'count'})
# Out:
#               PARTY
# PARTY
# Conservative  22299
# Labour        27301

# %%
import random

def RandomSample(data, size):
    """Returns random sample for given size
       If training data set is too big, we can reduce its size
    """
    return data.ix[random.sample(data.index, size)]


def StratifiedSample(data, nperlabel, label='label'):
    """Returns stratified data with N per label
    """
    sample = pd.DataFrame()
    datagrp = data.groupby(label)
    sortedgrp = datagrp.size().sort_values(ascending=False)
    for i, l in enumerate(sortedgrp.index):
        if sortedgrp[l] > nperlabel:
            print("==> %-50s %6d" % (l, sortedgrp[l]))
            sample = sample.append(RandomSample(data[data[label] == l],
                                   nperlabel))
        else:
            break
    print("There are %d labels have more than %d articles" % (i + 1, nperlabel))
    print("Sample size: %s articles" % (len(sample)))
    return sample

# %%
N_PER_LABEL = 10000

subset = StratifiedSample(sdf, N_PER_LABEL, 'PARTY')
# Out:
# ==> Labour                                              27301
# ==> Conservative                                        22299
# There are 2 labels have more than 10000 articles
# Sample size: 20000 articles

# %%
subset
# Out:
#                PARTY                                        SPEECH_TEXT  \
# 287829        Labour  come right hon friend secretari state said ear...
# 374642        Labour  amend would mean mayor spatial develop strateg...
# 173758        Labour  beg move bill read third time hous heard bill ...
# 71003         Labour  pleasur welcom hon gentleman dispatch box firs...
# 798879        Labour  pleasur respond debat right hon friend member ...
# 585383        Labour  hon friend absolut right perhap everybodi cham...
# 354555        Labour  one member select committe thank chairman memb...
# 175025        Labour  thank hon gentleman intervent mix natur farm p...
# 286000        Labour  hon gentleman ask mani question entir sure rep...
# 767791        Labour  alway listen hon friend member walthamstow muc...
# 248742        Labour  although would want say categor bernard ingham...
# 430063        Labour  least hon gentleman view consist difficulti co...
# 24688         Labour  initi intend thank front bench broadli nonpart...
# 506392        Labour  fish debat tend domin mp repres coastal consti...
# 499893        Labour  honour privileg constitu ask second loyal addr...
# 320189        Labour  beg move bill read third time pleasur introduc...
# 600472        Labour  follow visit last weekend baghdad basra would ...
# 4112          Labour  speech debat look back past year hon friend me...
# 415412        Labour  delight select present adjourn debat concern r...
# 198633        Labour  group amend deal consult rang issu amend remov...
# 335493        Labour  receiv rang view provis sort parti hon member ...
# 893089        Labour  delight particip debat passion support art cre...
# 382046        Labour  amend no associ one relat volunt realm volunta...
# 124391        Labour  apologis front bench present begin debat liste...
# 653928        Labour  hon friend right debat march commend report de...
# 577651        Labour  excel debat hon member present wide rang issu ...
# 377650        Labour  grate opportun report hous follow seriou alleg...
# 289134        Labour  although welcom fact liber democrat member tak...
# 269221        Labour  first fullday debat middl east govern time yea...
# 818127        Labour  beg move leav given bring bill make provis int...
# ...              ...                                                ...
# 179214  Conservative  much bill commend mani hon member alreadi said...
# 911014  Conservative  prioriti everi depart serv work pension commit...
# 230000  Conservative  grate secretari state intervent absolut right ...
# 927336  Conservative  grate minist comment constitu high level mesot...
# 225243  Conservative  glad speak debat bill nobl object everi hon me...
# 331437  Conservative  bill conceiv best intent promot throughout pas...
# 34507   Conservative  must begin thank parliamentari secretari minis...
# 731870  Conservative  hon friend make import point alway school unde...
# 446506  Conservative  may inde difficult offenc investig bring charg...
# 759128  Conservative  backbench busi debat christma recess spoke mag...
# 460568  Conservative  like hon friend member grantham stamford mr da...
# 707198  Conservative  secur debat bring attent hous murder three con...
# 67850   Conservative  wonder spirit crossparti accord begin congratu...
# 185115  Conservative  alway interest discov go debat progress partic...
# 230808  Conservative  commend hon friend member ashford mr green com...
# 428415  Conservative  draw attent hous entri regist member interest ...
# 604791  Conservative  great pleasur follow hon member southport dr p...
# 191059  Conservative  rather appropri discuss amend learn skill bill...
# 367381  Conservative  shall wait hon learn ladi make contribut later...
# 821149  Conservative  strongli support polici promot high speed inte...
# 10223   Conservative  hon friend say omiss statement budget fill gim...
# 615631  Conservative  wish rais concern alleg institutionalis fraud ...
# 423635  Conservative  problem hon member seek advic peopl know subje...
# 482303  Conservative  respect hon friend think bill adopt precis opp...
# 86778   Conservative  typic home secretari ask question talk engag o...
# 12099   Conservative  minist state said prime minist often claim edu...
# 389043  Conservative  thank financi secretari open remark first want...
# 692085  Conservative  accord bank intern settlement amount global de...
# 424292  Conservative  grate opportun speak final day debat budget re...
# 825849  Conservative  grate committe chairman say hope time finish r...
#
#         textlen
# 287829     3531
# 374642     2464
# 173758     3770
# 71003      4141
# 798879     5474
# 585383     2442
# 354555     2861
# 175025     3544
# 286000     4045
# 767791     2315
# 248742     2588
# 430063     2819
# 24688     10173
# 506392    11374
# 499893     4714
# 320189     5899
# 600472     6333
# 4112       4373
# 415412     6717
# 198633     2771
# 335493     3919
# 893089     2621
# 382046     2135
# 124391     2322
# 653928     2606
# 577651     2220
# 377650     2188
# 289134     3598
# 269221     2581
# 818127     3202
# ...         ...
# 179214     4304
# 911014     2304
# 230000     4615
# 927336     2259
# 225243     2369
# 331437     3177
# 34507      4415
# 731870     2320
# 446506     2556
# 759128     3169
# 460568     4514
# 707198     5552
# 67850      2256
# 185115     3470
# 230808     4614
# 428415     2703
# 604791     2415
# 191059     2024
# 367381     2563
# 821149     3151
# 10223      2683
# 615631     6666
# 423635     3557
# 482303     2513
# 86778      2344
# 12099      2320
# 389043     5816
# 692085     3822
# 424292     4044
# 825849     2479
#
# [20000 rows x 3 columns]

# %%
#subset.to_csv('/tmp/subset.csv.gz', compression='gzip', index=False)

# %%
import nltk
from nltk import word_tokenize          
from nltk.stem.porter import PorterStemmer
import re
import string

stemmer = PorterStemmer()
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

#def tokenize(text):
#    tokens = nltk.word_tokenize(text)
#    stems = stem_tokens(tokens, stemmer)
#    return stems

def tokenize(text):
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %%
with open('../roberts_rules/all_text.txt', 'rt') as f:
    text = f.read()
text = text.decode('ascii', 'ignore')
text = re.sub(r'\d+', '', text)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import svm
from sklearn.metrics import classification_report
from sklearn.cross_validation import train_test_split

# %%
vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3)) 
vect.fit([text])
roberts_rules = set(vect.get_feature_names())

# %%
X_train, X_test, y_train, y_test = train_test_split(subset.SPEECH_TEXT, subset.PARTY, test_size=0.2)

# %%
#all_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10)
all_vect = CountVectorizer(ngram_range=(2, 3), min_df=10)
all_vect.fit(X_train.astype(str))
vocab = []
i = 0
for a in all_vect.vocabulary_:
    if a not in roberts_rules:
        vocab.append(a)
    else:
        #print a
        i += 1
print("Removed {0:d}".format(i))
print("Total {0:d}".format(len(vocab)))
# Out:
# Removed 2558
# Total 137093

# %%
#train_vect = CountVectorizer(tokenizer=tokenize, stop_words='english', ngram_range=(2, 3), min_df=10, vocabulary=vocab)
train_vect = CountVectorizer(ngram_range=(2, 3), min_df=10, vocabulary=vocab)

# %%
X_train = train_vect.transform(X_train.astype(str))
transformer = TfidfTransformer()
X_train = transformer.fit_transform(X_train)

# %%
X_test = train_vect.transform(X_test.astype(str))
transformer = TfidfTransformer()
X_test = transformer.fit_transform(X_test)

# %%
from sklearn.linear_model import SGDClassifier

elastic_clf = SGDClassifier(loss='log', alpha=.00002, n_iter=200, penalty="elasticnet")
t0 = time.time()
elastic_clf.fit(X_train, y_train)
t1 = time.time()
prediction_elastic = elastic_clf.predict(X_test)
t2 = time.time()
time_elastic_train = t1-t0
time_elastic_predict = t2-t1

print("Results for Elastic Net")
print("Training time: %fs; Prediction time: %fs" % (time_elastic_train, time_elastic_predict))
print(classification_report(y_test, prediction_elastic))
# Out:
# Results for Elastic Net
# Training time: 16.385052s; Prediction time: 0.005898s
#              precision    recall  f1-score   support
#
# Conservative       0.81      0.82      0.82      2040
#      Labour       0.81      0.80      0.81      1960
#
# avg / total       0.81      0.81      0.81      4000

# %%
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print "\t%.4f\t%-20s\t\t%.4f\t%-20s" % (coef_1, fn_1, coef_2, fn_2)

# %%
show_most_informative_features(train_vect, elastic_clf, 100)
# Out:
# 	-7.6289	labour member       		9.8542	friend minist
# 	-5.8475	secretari state     		9.5322	hon friend minist
# 	-5.7485	hope minist         		6.1936	hon friend
# 	-5.4684	friend member south 		6.1585	right hon friend
# 	-5.4598	hon member birmingham		5.3760	hon gentleman
# 	-5.2105	right hon gentleman 		5.0759	opposit member
# 	-5.1785	labour parti        		4.9505	friend member birmingham
# 	-5.0096	friend member       		4.8833	conserv parti
# 	-4.5625	minist said         		4.7223	hon friend secretari
# 	-4.3310	offici report       		4.6856	friend secretari
# 	-4.2526	friend member bromley		4.6657	friend secretari state
# 	-4.1818	friend member north 		4.6444	hon member south
# 	-4.1406	hon member birkenhead		4.1273	tori govern
# 	-4.0875	hon learn friend    		3.9568	govern member
# 	-4.0701	hon member nottingham		3.8664	friend member leicest
# 	-3.9886	friend member southwest		3.8266	hon member southwest
# 	-3.9163	financi secretari   		3.8036	trade union
# 	-3.8638	hon member leicest  		3.7637	hon member bromley
# 	-3.8337	hon ladi            		3.6602	hon member stone
# 	-3.8079	learn friend        		3.6468	hon member wokingham
# 	-3.7499	minist know         		3.5258	hon friend home
# 	-3.7256	hon member glasgow  		3.5026	friend home
# 	-3.7245	learn friend member 		3.4090	friend member glasgow
# 	-3.6487	hon member liverpool		3.3548	friend member sheffield
# 	-3.6072	friend member christchurch		3.3279	tori parti
# 	-3.5706	hon friend member   		3.3224	friend home secretari
# 	-3.5040	paymast gener       		3.2666	friend member liverpool
# 	-3.3574	hon member hay      		3.2563	hon member haltempric
# 	-3.3086	taxpay money        		3.1892	friend member nottingham
# 	-3.3040	minist would        		3.0699	lib dem
# 	-3.2940	hous adjourn        		3.0623	hon learn gentleman
# 	-3.2862	friend member richmond		3.0394	learn gentleman
# 	-3.1212	agre hous adjourn   		2.9881	hon member richmond
# 	-3.1212	put agre hous       		2.9879	friend member linlithgow
# 	-3.0881	minist state        		2.9715	amend no
# 	-3.0677	chancellor exchequ  		2.9388	learn member
# 	-3.0601	friend member stone 		2.8397	hon learn member
# 	-3.0297	friend member gainsborough		2.8353	friend member hay
# 	-3.0211	grate minist        		2.8324	hon member huntingdon
# 	-3.0146	polit correct       		2.8178	south wale
# 	-2.9664	friend leader opposit		2.7899	hon member woodspr
# 	-2.9596	friend member haltempric		2.7351	opposit parti
# 	-2.9522	minist may          		2.7101	hon member penrith
# 	-2.9514	friend member wokingham		2.7003	hon member gainsborough
# 	-2.9116	coalit govern       		2.7002	hon member north
# 	-2.8864	yet anoth           		2.6740	labour govern
# 	-2.8486	red book            		2.6309	hon member suffolk
# 	-2.8480	district council    		2.6016	young peopl
# 	-2.8310	friend member hitchin		2.5722	local govern
# 	-2.8243	hon member edinburgh		2.5703	adjourn accordingli
# 	-2.8084	govern propos       		2.5673	tax cut
# 	-2.8038	friend member northeast		2.5641	peopl work
# 	-2.7948	commun hospit       		2.5523	hon member sutton
# 	-2.7686	hon member hendon   		2.5463	hon member maidenhead
# 	-2.7651	friend member new   		2.5346	friend member great
# 	-2.7279	agre hous           		2.5304	put agre adjourn
# 	-2.7193	stealth tax         		2.5304	agre adjourn accordingli
# 	-2.6890	friend member buckingham		2.5304	agre adjourn
# 	-2.6825	hon member manchest 		2.5285	hon member new
# 	-2.6727	friend member penrith		2.5029	friend member wolverhampton
# 	-2.6711	minist made         		2.4964	friend member bolton
# 	-2.6411	friend member sutton		2.4722	learn member rushcliff
# 	-2.6321	hon member newcastl 		2.4657	friend member cardiff
# 	-2.6280	friend member suffolk		2.4630	hon member bournemouth
# 	-2.5981	hon member lewisham 		2.4427	friend member islington
# 	-2.5920	hon member walsal   		2.4404	hon member buckingham
# 	-2.5789	hon member rhondda  		2.4287	intern commun
# 	-2.5641	would like          		2.4265	greater manchest
# 	-2.5368	chief secretari     		2.4252	friend member hendon
# 	-2.5339	hon member linlithgow		2.4104	hon member skipton
# 	-2.5167	econom secretari    		2.3932	hon member east
# 	-2.5148	friend member east  		2.3634	hon member maidston
# 	-2.5101	prime minist        		2.3620	friend member newcastl
# 	-2.5037	friend member witney		2.3594	hon member beaconsfield
# 	-2.4953	may well            		2.3370	hon member
# 	-2.4871	one could           		2.3272	friend member brent
# 	-2.4862	rural area          		2.3269	friend member manchest
# 	-2.4677	friend member maidston		2.3219	conserv member
# 	-2.4565	new labour          		2.3114	help us
# 	-2.4523	cold war            		2.2813	council hous
# 	-2.4411	minist agre         		2.2764	hon member tiverton
# 	-2.4394	govern fail         		2.2571	friend member birkenhead
# 	-2.4381	one two             		2.2538	hon member northwest
# 	-2.4201	social worker       		2.2296	friend prime
# 	-2.4165	govern intend       		2.2252	hon friend chancellor
# 	-2.3835	sure minist         		2.2234	friend member rhondda
# 	-2.3815	valu money          		2.2198	friend leader hous
# 	-2.3774	group amend         		2.2196	hon member chichest
# 	-2.3595	friend member bournemouth		2.2163	suppli chain
# 	-2.3552	hon member islington		2.2154	hous benefit
# 	-2.3517	counti council      		2.2129	friend prime minist
# 	-2.3495	hon member luton    		2.2081	bedroom tax
# 	-2.3395	intern develop      		2.2001	hon member hitchin
# 	-2.3340	friend member huntingdon		2.1959	assur hon
# 	-2.3169	enterpris zone      		2.1818	friend foreign
# 	-2.3042	health care         		2.1719	video game
# 	-2.3037	region assembl      		2.1715	friend chancellor
# 	-2.3031	hon member holborn  		2.1697	hon member runnymed
# 	-2.2938	council tax         		2.1693	hon member arundel
# 	-2.2936	hon member wakefield		2.1677	friend member walsal

# %%
elastic_clf.predict_proba(X_test)
# Out:
# array([[ 0.15689238,  0.84310762],
#        [ 0.05752817,  0.94247183],
#        [ 0.16306576,  0.83693424],
#        ...,
#        [ 0.33880761,  0.66119239],
#        [ 0.57376833,  0.42623167],
#        [ 0.7484129 ,  0.2515871 ]])

# %%
X_test.shape
# Out:
# (4000, 137093)

# %% [markdown]
# ## Save model to files

# %%
from sklearn.externals import joblib

#joblib.dump(train_vect, "../models/vec_count_23gram_081.joblib")
#joblib.dump(elastic_clf, "../models/clf_elasticnet_081.joblib")
# Out:
# ['../models/clf_elasticnet_081.joblib',
#  '../models/clf_elasticnet_081.joblib_01.npy',
#  '../models/clf_elasticnet_081.joblib_02.npy',
#  '../models/clf_elasticnet_081.joblib_03.npy',
#  '../models/clf_elasticnet_081.joblib_04.npy']

# %%
def get_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names))
    top_a = coefs_with_fns[:n]
    top_b = coefs_with_fns[:-(n + 1):-1]
    return top_a, top_b

top_a, top_b = get_most_informative_features(train_vect, elastic_clf, 100)
top_a_df = pd.DataFrame(top_a)
top_a_df.columns = ['coef', 'term']
top_b_df = pd.DataFrame(top_b)
top_b_df.columns = ['coef', 'term']
top_a_df.to_csv('../data/top10_cons_1.csv', index=False)
top_b_df.to_csv('../data/top10_lab_1.csv', index=False)
